# %% [markdown]
# <a href="https://colab.research.google.com/github/Danangellotti/Ciencia_de_Datos_UGR_24/blob/main/Semana_06_Tema_02_Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [spacy](https://spacy.io/)
#
#
# Librería de Python para el procesamiento del lenguaje natural que esparticularmente rápido e intuitivo, proporciona modelos preentrenados en diferentes lenguajes, lo cual junto a una sintaxis clara hace que sea ideal para principiantes en el campo de la NLP.
#
# Los modelos pre entrenados utilizan la aquitectura de transformers.

# %% [markdown]
# ## Instalación

# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.9/dist-packages (3.5.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (23.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy) (8.1.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.1.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy) (1.10.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy) (67.6.1)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy) (2.1.2)

# %% [markdown]
# ## Versión

# %%
import spacy
spacy.__version__
# Out:
# '3.5.2'

# %%
# para generar nuestro propio lenguaje
# from spacy.tokenizer import Tokenizer
# from spacy.lang.es import Spanish
# nlp_spanish = Spanish()

# %% [markdown]
# ## [Configuración y descarga de modelos](https://spacy.io/models)
#
# Por defecto viene configurada para trabajar en inglés por lo tanto debemos descargar o utilizar librerías de español.
#
# En nuestro caso vamos a descargar un modelo sencillo pero podemos utilizar otros más potentes.

# %%
# descargo el modelo
# !python -m spacy download es_core_news_sm

# importo el modelo
import spacy
nlp_es_sm = spacy.load("es_core_news_sm")
# Out:
# 2023-04-21 08:34:48.155262: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.5.0/es_core_news_sm-3.5.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from es-core-news-sm==3.5.0) (3.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (23.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.4.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.22.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.27.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (8.1.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (67.6.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.10.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (4.65.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->es-core-news-sm==3.5.0) (2.1.2)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %% [markdown]
# ## [Tokenizador y tokens](https://www.nltk.org/api/nltk.tokenize.html)
#
# Un tokenizador es una herramienta que se utiliza en el procesamiento del lenguaje natural para dividir un texto en palabras individuales o en frases más pequeñas llamadas tokens. El proceso de tokenización implica la separación de signos de puntuación y caracteres especiales y la separación de las palabras en un texto.
#
# Existen varios tipos de tokenizadores, algunos dividen las palabras en sub palabras.
#
#
# Algunas propiedas que son comunes a los string
#
# | Función | Descripción |
# | --- | --- |
# | lower_ | Devuelve el token en minúscula |
# | is_alpha | Contiene letras del alfabeto |
# | is_ascii | Posee todos caracteres ASCII (128) |
# | is_digit | Es un dígito |
# | is_lower | Está en minúscula? |
# | is_upper | Está en mayúscula? |
# | is_title | Está en título o capitalizado? |
# | is_punct | Es un caracter de puntuación? |
# | is_left_punct | Es un caracter de puntuación izquierdo? Por ejemplo ( [ { |
# | is_right_punct | Es un caracter de puntuación izquierdo? Por ejemplo ) ] } |
# | is_sent_start | Está comenzando una sentencia u oración? |
# | is_sent_end | Está finalizando una sentencia u oración? |
# | is_space | Es un espacio o tab |
# | is_bracket | Es un corchete? |
# | is_quote | Es una cita? |
# | is_currency | Es un simbolo de moneda? |
# | like_url | Es una url? |
# | like_num | Es un número? |
# | like_email | Es un email? |
# | is_oov | Está fuera del vocabulario del idioma? |
# | is_stop | Es un stop word? |

# %%
texto = """La inteligencia artificial (IA), en el contexto de las ciencias de la
computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
propósito es crear máquinas que imitan la inteligencia humana para realizar
tareas y pueden mejorar conforme la información que recopilan. La inteligencia
artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
significativamente las capacidades y contribuciones humanas. Se hizo presente
poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
informático John McCarthy, en la Conferencia de Dartmouth."""
# Fijense como separó las palabras, los caracteres especiales tienen su propio
# lugar en la lista, no están pegadas a las palabras.

# La función de tokenizador me devuelve algo del tipo Doc (https://spacy.io/api/doc)
# El objeto Doc contiene un array de structs TokenC. Los objetos Token y Span a
# nivel Python son vistas de esta matriz, es decir, no poseen los datos en sí.
text_doc = nlp_es_sm(texto)

# %%
# vamos a ver los tokens
print([t for t in text_doc])
# Out:
# [La, inteligencia, artificial, (, IA, ), ,, en, el, contexto, de, las, ciencias, de, la,
# , computación, ,, es, el, conjunto, de, sistemas, o, combinación, de, algoritmos, ,, cuyo,
# , propósito, es, crear, máquinas, que, imitan, la, inteligencia, humana, para, realizar,
# , tareas, y, pueden, mejorar, conforme, la, información, que, recopilan, ., La, inteligencia,
# , artificial, no, tiene, como, finalidad, reemplazar, a, los, humanos, ,, sino, mejorar,
# , significativamente, las, capacidades, y, contribuciones, humanas, ., Se, hizo, presente,
# , poco, después, de, la, Segunda, Guerra, Mundial, ,, y, el, nombre, lo, acuñó, en, 1956, el,
# , informático, John, McCarthy, ,, en, la, Conferencia, de, Dartmouth, .]

# %% [markdown]
# ### Propiedades de un token

# %% [markdown]
# #### Obteniendo sentencias u oraciones

# %%
# Para obtener las sentencias debemos pedirle al Doc la propiedad sents
print([ sent for sent in text_doc.sents])
# Out:
# [La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan., La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas., Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.]

# %% [markdown]
# #### Obteniendo la palabra y la sentencia a la que pertenece

# %%
# Para obtener esto, debemos recorrer el Doc y mostrar la palabra y la sentencia relacionada
# Notar que estmos mostrando una tupla donde el primer elemento es la palabra y
# el segundo elemento es la sentencia a la que pertenece esa palabra.
print([ (word, word.sent) for word in text_doc])
# Out:
# [(La, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (inteligencia, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (artificial, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), ((, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (IA, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (), La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (,, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (en, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (el, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (contexto, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (de, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (las, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (ciencias, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (de, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (la, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (
# , La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (computación, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (,, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (es, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (el, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (conjunto, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (de, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (sistemas, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (o, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (combinación, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (de, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (algoritmos, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (,, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (cuyo, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (
# , La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (propósito, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (es, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (crear, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (máquinas, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (que, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (imitan, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (la, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (inteligencia, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (humana, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (para, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (realizar, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (
# , La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (tareas, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (y, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (pueden, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (mejorar, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (conforme, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (la, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (información, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (que, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (recopilan, La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (., La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan.), (La, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (inteligencia, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (
# , La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (artificial, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (no, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (tiene, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (como, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (finalidad, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (reemplazar, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (a, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (los, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (humanos, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (,, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (sino, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (mejorar, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (
# , La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (significativamente, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (las, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (capacidades, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (y, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (contribuciones, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (humanas, La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (., La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas.), (Se, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (hizo, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (presente, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (
# , Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (poco, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (después, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (de, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (la, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (Segunda, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (Guerra, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (Mundial, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (,, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (y, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (el, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (nombre, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (lo, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (acuñó, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (en, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (1956, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (el, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (
# , Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (informático, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (John, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (McCarthy, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (,, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (en, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (la, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (Conferencia, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (de, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (Dartmouth, Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.), (., Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth
# %% [markdown]
# #### Obteniendo la posición dentro de la sentencia

# %%
# Con la propiedad i obtenemos la posición del token dentro de la sentencia.
# Con la propiedad idx obtenemos la posición del caracter dentro de la sentencia.
# El idx me permite hacer slice del texto
print([(word, word.i, word.idx) for word in text_doc])

print()
print("Mostramos el slice según los primeros tokens:")
print("Sentencia: text_doc[0].idx - text_doc[1].idx: texto[text_doc[0].idx:text_doc[1].idx]")
print(f"{text_doc[0].idx} - {text_doc[1].idx}: {texto[text_doc[0].idx:text_doc[1].idx]}")
print()
print("Sentencia: text_doc[1].idx - text_doc[2].idx: texto[text_doc[1].idx:text_doc[2].idx]")
print(f"{text_doc[1].idx} - {text_doc[2].idx}: {texto[text_doc[1].idx:text_doc[2].idx]}")
# Out:
# [(La, 0, 0), (inteligencia, 1, 3), (artificial, 2, 16), ((, 3, 27), (IA, 4, 28), (), 5, 30), (,, 6, 31), (en, 7, 33), (el, 8, 36), (contexto, 9, 39), (de, 10, 48), (las, 11, 51), (ciencias, 12, 55), (de, 13, 64), (la, 14, 67), (
# , 15, 70), (computación, 16, 71), (,, 17, 82), (es, 18, 84), (el, 19, 87), (conjunto, 20, 90), (de, 21, 99), (sistemas, 22, 102), (o, 23, 111), (combinación, 24, 113), (de, 25, 125), (algoritmos, 26, 128), (,, 27, 138), (cuyo, 28, 140), (
# , 29, 145), (propósito, 30, 146), (es, 31, 156), (crear, 32, 159), (máquinas, 33, 165), (que, 34, 174), (imitan, 35, 178), (la, 36, 185), (inteligencia, 37, 188), (humana, 38, 201), (para, 39, 208), (realizar, 40, 213), (
# , 41, 222), (tareas, 42, 223), (y, 43, 230), (pueden, 44, 232), (mejorar, 45, 239), (conforme, 46, 247), (la, 47, 256), (información, 48, 259), (que, 49, 271), (recopilan, 50, 275), (., 51, 284), (La, 52, 286), (inteligencia, 53, 289), (
# , 54, 302), (artificial, 55, 303), (no, 56, 314), (tiene, 57, 317), (como, 58, 323), (finalidad, 59, 328), (reemplazar, 60, 338), (a, 61, 349), (los, 62, 351), (humanos, 63, 355), (,, 64, 362), (sino, 65, 364), (mejorar, 66, 369), (
# , 67, 377), (significativamente, 68, 378), (las, 69, 397), (capacidades, 70, 401), (y, 71, 413), (contribuciones, 72, 415), (humanas, 73, 430), (., 74, 437), (Se, 75, 439), (hizo, 76, 442), (presente, 77, 447), (
# , 78, 456), (poco, 79, 457), (después, 80, 462), (de, 81, 470), (la, 82, 473), (Segunda, 83, 476), (Guerra, 84, 484), (Mundial, 85, 491), (,, 86, 498), (y, 87, 500), (el, 88, 502), (nombre, 89, 505), (lo, 90, 512), (acuñó, 91, 515), (en, 92, 521), (1956, 93, 524), (el, 94, 529), (
# , 95, 532), (informático, 96, 533), (John, 97, 545), (McCarthy, 98, 550), (,, 99, 558), (en, 100, 560), (la, 101, 563), (Conferencia, 102, 566), (de, 103, 578), (Dartmouth, 104, 581), (., 105, 590)]
#
# Mostramos el slice según los primeros tokens:
# Sentencia: text_doc[0].idx - text_doc[1].idx: texto[text_doc[0].idx:text_doc[1].idx]
# 0 - 3: La
#
# Sentencia: text_doc[1].idx - text_doc[2].idx: texto[text_doc[1].idx:text_doc[2].idx]
# 3 - 16: inteligencia

# %% [markdown]
# #### Obteniendo la entidad o ner (name enetity recognition)
#
# Identifica y clasifica nombres de entidades en un texto en categorías predefinidas, como nombres de personas, organizaciones, lugares, fechas, cantidades, entre otros.
#
# El objetivo del NER es extraer información relevante del texto, identificando las entidades nombradas y clasificándolas según su tipo, para luego poder analizarlas y utilizarlas en diferentes aplicaciones, como la extracción de información, la recuperación de información, la traducción automática, la resumen de textos, entre otros.
#
# Por ejemplo, si se tiene un texto que menciona el nombre "Steve Jobs", un NER identificaría que "Steve Jobs" es una entidad nombrada de tipo "persona". Si el texto también menciona el nombre de una empresa como "Apple", el NER identificaría que "Apple" es una entidad nombrada de tipo "organización".

# %%
# Para este modelo sencillo podemos ver que solo identifica MISC y PER
print([(word, word.ent_type_) for word in text_doc])
# Out:
# [(La, ''), (inteligencia, ''), (artificial, ''), ((, ''), (IA, ''), (), ''), (,, ''), (en, ''), (el, ''), (contexto, ''), (de, ''), (las, ''), (ciencias, ''), (de, ''), (la, ''), (
# , ''), (computación, ''), (,, ''), (es, ''), (el, ''), (conjunto, ''), (de, ''), (sistemas, ''), (o, ''), (combinación, ''), (de, ''), (algoritmos, ''), (,, ''), (cuyo, ''), (
# , ''), (propósito, ''), (es, ''), (crear, ''), (máquinas, ''), (que, ''), (imitan, ''), (la, ''), (inteligencia, ''), (humana, ''), (para, ''), (realizar, ''), (
# , ''), (tareas, ''), (y, ''), (pueden, ''), (mejorar, ''), (conforme, ''), (la, ''), (información, ''), (que, ''), (recopilan, ''), (., ''), (La, 'MISC'), (inteligencia, 'MISC'), (
# , 'MISC'), (artificial, 'MISC'), (no, 'MISC'), (tiene, 'MISC'), (como, 'MISC'), (finalidad, 'MISC'), (reemplazar, ''), (a, ''), (los, ''), (humanos, ''), (,, ''), (sino, ''), (mejorar, ''), (
# , ''), (significativamente, ''), (las, ''), (capacidades, ''), (y, ''), (contribuciones, ''), (humanas, ''), (., ''), (Se, ''), (hizo, ''), (presente, ''), (
# , ''), (poco, ''), (después, ''), (de, ''), (la, ''), (Segunda, 'MISC'), (Guerra, 'MISC'), (Mundial, 'MISC'), (,, ''), (y, ''), (el, ''), (nombre, ''), (lo, ''), (acuñó, ''), (en, ''), (1956, ''), (el, ''), (
# , ''), (informático, ''), (John, 'PER'), (McCarthy, 'PER'), (,, ''), (en, ''), (la, ''), (Conferencia, 'MISC'), (de, 'MISC'), (Dartmouth, 'MISC'), (., '')]

# %% [markdown]
# #### Obteniendo el lemma (lemmatizer)
#
# Convierte las palabras en su forma base, conocida como "lema". El lema es la forma de la palabra que se encuentra en un diccionario y representa su significado principal.
#
# El proceso de lematización es similar a la reducción de una palabra a su raíz, pero en lugar de simplemente eliminar los sufijos y prefijos, el lematizador utiliza un conocimiento más profundo del idioma para identificar la forma base correcta de una palabra en función del contexto en el que se utiliza.
#
# Por ejemplo:
#
# | Palabra | Lemma |
# | --- | --- |
# | corriendo | correr |
# | corre | correr |
# | cantando | cantar |
# | comiendo | comer |
# | gatos | gato |
# | mejores | mejor |
# | hablando | hablar |
# | felicidad | felicidad |
# | leyendo | leer |
# | bailando | bailar |
# | trabajadores | trabajador |
#
# `Spacy no posee con stem o stemming, lo vamos a ver con nltk`.

# %%
print([(word, word.lemma_) for word in text_doc])
# Out:
# [(La, 'el'), (inteligencia, 'inteligencia'), (artificial, 'artificial'), ((, '('), (IA, 'IA'), (), ')'), (,, ','), (en, 'en'), (el, 'el'), (contexto, 'contexto'), (de, 'de'), (las, 'el'), (ciencias, 'ciencia'), (de, 'de'), (la, 'el'), (
# , '\n'), (computación, 'computación'), (,, ','), (es, 'ser'), (el, 'el'), (conjunto, 'conjunto'), (de, 'de'), (sistemas, 'sistema'), (o, 'o'), (combinación, 'combinación'), (de, 'de'), (algoritmos, 'algoritmo'), (,, ','), (cuyo, 'cuyo'), (
# , '\n'), (propósito, 'propósito'), (es, 'ser'), (crear, 'crear'), (máquinas, 'máquina'), (que, 'que'), (imitan, 'imitar'), (la, 'el'), (inteligencia, 'inteligencia'), (humana, 'humano'), (para, 'para'), (realizar, 'realizar'), (
# , '\n'), (tareas, 'tarea'), (y, 'y'), (pueden, 'poder'), (mejorar, 'mejorar'), (conforme, 'conforme'), (la, 'el'), (información, 'información'), (que, 'que'), (recopilan, 'recopilir'), (., '.'), (La, 'el'), (inteligencia, 'inteligencia'), (
# , '\n'), (artificial, 'artificial'), (no, 'no'), (tiene, 'tener'), (como, 'como'), (finalidad, 'finalidad'), (reemplazar, 'reemplazar'), (a, 'a'), (los, 'el'), (humanos, 'humano'), (,, ','), (sino, 'sino'), (mejorar, 'mejorar'), (
# , '\n'), (significativamente, 'significativamente'), (las, 'el'), (capacidades, 'capacidad'), (y, 'y'), (contribuciones, 'contribución'), (humanas, 'humano'), (., '.'), (Se, 'él'), (hizo, 'hacer'), (presente, 'presente'), (
# , '\n'), (poco, 'poco'), (después, 'después'), (de, 'de'), (la, 'el'), (Segunda, 'Segunda'), (Guerra, 'Guerra'), (Mundial, 'Mundial'), (,, ','), (y, 'y'), (el, 'el'), (nombre, 'nombre'), (lo, 'él'), (acuñó, 'acuñó'), (en, 'en'), (1956, '1956'), (el, 'el'), (
# , '\n'), (informático, 'informático'), (John, 'John'), (McCarthy, 'McCarthy'), (,, ','), (en, 'en'), (la, 'el'), (Conferencia, 'Conferencia'), (de, 'de'), (Dartmouth, 'Dartmouth'), (., '.')]

# %% [markdown]
# #### Obteniendo la normalización del token

# %%
print([(word, word.norm_) for word in text_doc])
# Out:
# [(La, 'la'), (inteligencia, 'inteligencia'), (artificial, 'artificial'), ((, '('), (IA, 'ia'), (), ')'), (,, ','), (en, 'en'), (el, 'el'), (contexto, 'contexto'), (de, 'de'), (las, 'las'), (ciencias, 'ciencias'), (de, 'de'), (la, 'la'), (
# , '\n'), (computación, 'computación'), (,, ','), (es, 'es'), (el, 'el'), (conjunto, 'conjunto'), (de, 'de'), (sistemas, 'sistemas'), (o, 'o'), (combinación, 'combinación'), (de, 'de'), (algoritmos, 'algoritmos'), (,, ','), (cuyo, 'cuyo'), (
# , '\n'), (propósito, 'propósito'), (es, 'es'), (crear, 'crear'), (máquinas, 'máquinas'), (que, 'que'), (imitan, 'imitan'), (la, 'la'), (inteligencia, 'inteligencia'), (humana, 'humana'), (para, 'para'), (realizar, 'realizar'), (
# , '\n'), (tareas, 'tareas'), (y, 'y'), (pueden, 'pueden'), (mejorar, 'mejorar'), (conforme, 'conforme'), (la, 'la'), (información, 'información'), (que, 'que'), (recopilan, 'recopilan'), (., '.'), (La, 'la'), (inteligencia, 'inteligencia'), (
# , '\n'), (artificial, 'artificial'), (no, 'no'), (tiene, 'tiene'), (como, 'como'), (finalidad, 'finalidad'), (reemplazar, 'reemplazar'), (a, 'a'), (los, 'los'), (humanos, 'humanos'), (,, ','), (sino, 'sino'), (mejorar, 'mejorar'), (
# , '\n'), (significativamente, 'significativamente'), (las, 'las'), (capacidades, 'capacidades'), (y, 'y'), (contribuciones, 'contribuciones'), (humanas, 'humanas'), (., '.'), (Se, 'se'), (hizo, 'hizo'), (presente, 'presente'), (
# , '\n'), (poco, 'poco'), (después, 'después'), (de, 'de'), (la, 'la'), (Segunda, 'segunda'), (Guerra, 'guerra'), (Mundial, 'mundial'), (,, ','), (y, 'y'), (el, 'el'), (nombre, 'nombre'), (lo, 'lo'), (acuñó, 'acuñó'), (en, 'en'), (1956, '1956'), (el, 'el'), (
# , '\n'), (informático, 'informático'), (John, 'john'), (McCarthy, 'mccarthy'), (,, ','), (en, 'en'), (la, 'la'), (Conferencia, 'conferencia'), (de, 'de'), (Dartmouth, 'dartmouth'), (., '.')]

# %% [markdown]
# #### Obteniendo el prefijo o sufijo
#
# El prefijo viene configurado por defecto para obtener el primer caracter.
#
# El sufijo viene configurado por defecto para obtener los últimos 3 caracter.

# %%
print([(word, word.prefix_, word.suffix_) for word in text_doc])
# Out:
# [(La, 'L', 'La'), (inteligencia, 'i', 'cia'), (artificial, 'a', 'ial'), ((, '(', '('), (IA, 'I', 'IA'), (), ')', ')'), (,, ',', ','), (en, 'e', 'en'), (el, 'e', 'el'), (contexto, 'c', 'xto'), (de, 'd', 'de'), (las, 'l', 'las'), (ciencias, 'c', 'ias'), (de, 'd', 'de'), (la, 'l', 'la'), (
# , '\n', '\n'), (computación, 'c', 'ión'), (,, ',', ','), (es, 'e', 'es'), (el, 'e', 'el'), (conjunto, 'c', 'nto'), (de, 'd', 'de'), (sistemas, 's', 'mas'), (o, 'o', 'o'), (combinación, 'c', 'ión'), (de, 'd', 'de'), (algoritmos, 'a', 'mos'), (,, ',', ','), (cuyo, 'c', 'uyo'), (
# , '\n', '\n'), (propósito, 'p', 'ito'), (es, 'e', 'es'), (crear, 'c', 'ear'), (máquinas, 'm', 'nas'), (que, 'q', 'que'), (imitan, 'i', 'tan'), (la, 'l', 'la'), (inteligencia, 'i', 'cia'), (humana, 'h', 'ana'), (para, 'p', 'ara'), (realizar, 'r', 'zar'), (
# , '\n', '\n'), (tareas, 't', 'eas'), (y, 'y', 'y'), (pueden, 'p', 'den'), (mejorar, 'm', 'rar'), (conforme, 'c', 'rme'), (la, 'l', 'la'), (información, 'i', 'ión'), (que, 'q', 'que'), (recopilan, 'r', 'lan'), (., '.', '.'), (La, 'L', 'La'), (inteligencia, 'i', 'cia'), (
# , '\n', '\n'), (artificial, 'a', 'ial'), (no, 'n', 'no'), (tiene, 't', 'ene'), (como, 'c', 'omo'), (finalidad, 'f', 'dad'), (reemplazar, 'r', 'zar'), (a, 'a', 'a'), (los, 'l', 'los'), (humanos, 'h', 'nos'), (,, ',', ','), (sino, 's', 'ino'), (mejorar, 'm', 'rar'), (
# , '\n', '\n'), (significativamente, 's', 'nte'), (las, 'l', 'las'), (capacidades, 'c', 'des'), (y, 'y', 'y'), (contribuciones, 'c', 'nes'), (humanas, 'h', 'nas'), (., '.', '.'), (Se, 'S', 'Se'), (hizo, 'h', 'izo'), (presente, 'p', 'nte'), (
# , '\n', '\n'), (poco, 'p', 'oco'), (después, 'd', 'ués'), (de, 'd', 'de'), (la, 'l', 'la'), (Segunda, 'S', 'nda'), (Guerra, 'G', 'rra'), (Mundial, 'M', 'ial'), (,, ',', ','), (y, 'y', 'y'), (el, 'e', 'el'), (nombre, 'n', 'bre'), (lo, 'l', 'lo'), (acuñó, 'a', 'uñó'), (en, 'e', 'en'), (1956, '1', '956'), (el, 'e', 'el'), (
# , '\n', '\n'), (informático, 'i', 'ico'), (John, 'J', 'ohn'), (McCarthy, 'M', 'thy'), (,, ',', ','), (en, 'e', 'en'), (la, 'l', 'la'), (Conferencia, 'C', 'cia'), (de, 'd', 'de'), (Dartmouth, 'D', 'uth'), (., '.', '.')]

# %% [markdown]
# #### [Análisis sintáctico o part of speech](https://universaldependencies.org/u/pos/)

# %%
print([(word, word.pos_) for word in text_doc])
# Out:
# [(La, 'DET'), (inteligencia, 'NOUN'), (artificial, 'ADJ'), ((, 'PUNCT'), (IA, 'PROPN'), (), 'PUNCT'), (,, 'PUNCT'), (en, 'ADP'), (el, 'DET'), (contexto, 'NOUN'), (de, 'ADP'), (las, 'DET'), (ciencias, 'NOUN'), (de, 'ADP'), (la, 'DET'), (
# , 'SPACE'), (computación, 'NOUN'), (,, 'PUNCT'), (es, 'AUX'), (el, 'DET'), (conjunto, 'NOUN'), (de, 'ADP'), (sistemas, 'NOUN'), (o, 'CCONJ'), (combinación, 'NOUN'), (de, 'ADP'), (algoritmos, 'NOUN'), (,, 'PUNCT'), (cuyo, 'PRON'), (
# , 'SPACE'), (propósito, 'NOUN'), (es, 'AUX'), (crear, 'VERB'), (máquinas, 'NOUN'), (que, 'PRON'), (imitan, 'VERB'), (la, 'DET'), (inteligencia, 'NOUN'), (humana, 'ADJ'), (para, 'ADP'), (realizar, 'VERB'), (
# , 'SPACE'), (tareas, 'NOUN'), (y, 'CCONJ'), (pueden, 'AUX'), (mejorar, 'VERB'), (conforme, 'ADP'), (la, 'DET'), (información, 'NOUN'), (que, 'PRON'), (recopilan, 'VERB'), (., 'PUNCT'), (La, 'DET'), (inteligencia, 'NOUN'), (
# , 'SPACE'), (artificial, 'ADJ'), (no, 'ADV'), (tiene, 'VERB'), (como, 'SCONJ'), (finalidad, 'NOUN'), (reemplazar, 'VERB'), (a, 'ADP'), (los, 'DET'), (humanos, 'NOUN'), (,, 'PUNCT'), (sino, 'CCONJ'), (mejorar, 'VERB'), (
# , 'SPACE'), (significativamente, 'ADV'), (las, 'DET'), (capacidades, 'NOUN'), (y, 'CCONJ'), (contribuciones, 'NOUN'), (humanas, 'ADJ'), (., 'PUNCT'), (Se, 'PRON'), (hizo, 'VERB'), (presente, 'ADJ'), (
# , 'SPACE'), (poco, 'ADV'), (después, 'ADV'), (de, 'ADP'), (la, 'DET'), (Segunda, 'PROPN'), (Guerra, 'PROPN'), (Mundial, 'PROPN'), (,, 'PUNCT'), (y, 'CCONJ'), (el, 'DET'), (nombre, 'NOUN'), (lo, 'PRON'), (acuñó, 'VERB'), (en, 'ADP'), (1956, 'NOUN'), (el, 'DET'), (
# , 'SPACE'), (informático, 'NOUN'), (John, 'PROPN'), (McCarthy, 'PROPN'), (,, 'PUNCT'), (en, 'ADP'), (la, 'DET'), (Conferencia, 'PROPN'), (de, 'ADP'), (Dartmouth, 'PROPN'), (., 'PUNCT')]

# %%
from spacy import displacy
displacy.render(text_doc, style="dep", jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="d93fd8b534aa44649df6634e898ebe37-0" class="displacy" width="8600" height="407.0" direction="ltr" style="max-width: none; height: 407.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">inteligencia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">artificial (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">IA),</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">contexto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">las</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">ciencias</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">computación,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">el</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">conjunto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">sistemas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">o</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">combinación</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">algoritmos,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">cuyo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">propósito</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">crear</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">máquinas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">que</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="317.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">imitan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x

# %% [markdown]
# #### Obteniendo el idioma del token

# %%
print([(word, word.lang_) for word in text_doc])
# Out:
# [(La, 'es'), (inteligencia, 'es'), (artificial, 'es'), ((, 'es'), (IA, 'es'), (), 'es'), (,, 'es'), (en, 'es'), (el, 'es'), (contexto, 'es'), (de, 'es'), (las, 'es'), (ciencias, 'es'), (de, 'es'), (la, 'es'), (
# , 'es'), (computación, 'es'), (,, 'es'), (es, 'es'), (el, 'es'), (conjunto, 'es'), (de, 'es'), (sistemas, 'es'), (o, 'es'), (combinación, 'es'), (de, 'es'), (algoritmos, 'es'), (,, 'es'), (cuyo, 'es'), (
# , 'es'), (propósito, 'es'), (es, 'es'), (crear, 'es'), (máquinas, 'es'), (que, 'es'), (imitan, 'es'), (la, 'es'), (inteligencia, 'es'), (humana, 'es'), (para, 'es'), (realizar, 'es'), (
# , 'es'), (tareas, 'es'), (y, 'es'), (pueden, 'es'), (mejorar, 'es'), (conforme, 'es'), (la, 'es'), (información, 'es'), (que, 'es'), (recopilan, 'es'), (., 'es'), (La, 'es'), (inteligencia, 'es'), (
# , 'es'), (artificial, 'es'), (no, 'es'), (tiene, 'es'), (como, 'es'), (finalidad, 'es'), (reemplazar, 'es'), (a, 'es'), (los, 'es'), (humanos, 'es'), (,, 'es'), (sino, 'es'), (mejorar, 'es'), (
# , 'es'), (significativamente, 'es'), (las, 'es'), (capacidades, 'es'), (y, 'es'), (contribuciones, 'es'), (humanas, 'es'), (., 'es'), (Se, 'es'), (hizo, 'es'), (presente, 'es'), (
# , 'es'), (poco, 'es'), (después, 'es'), (de, 'es'), (la, 'es'), (Segunda, 'es'), (Guerra, 'es'), (Mundial, 'es'), (,, 'es'), (y, 'es'), (el, 'es'), (nombre, 'es'), (lo, 'es'), (acuñó, 'es'), (en, 'es'), (1956, 'es'), (el, 'es'), (
# , 'es'), (informático, 'es'), (John, 'es'), (McCarthy, 'es'), (,, 'es'), (en, 'es'), (la, 'es'), (Conferencia, 'es'), (de, 'es'), (Dartmouth, 'es'), (., 'es')]

# %% [markdown]
# #### Obteniendo la posición
#
# La propiedad i me da la posición de la palabra dentro de la lista de tokens.
#
# La propiedad idx me da la posición del caracter donde comienza la palabra.

# %%
print([(word, word.i, word.idx) for word in text_doc])
# Out:
# [(La, 0, 0), (inteligencia, 1, 3), (artificial, 2, 16), ((, 3, 27), (IA, 4, 28), (), 5, 30), (,, 6, 31), (en, 7, 33), (el, 8, 36), (contexto, 9, 39), (de, 10, 48), (las, 11, 51), (ciencias, 12, 55), (de, 13, 64), (la, 14, 67), (
# , 15, 70), (computación, 16, 71), (,, 17, 82), (es, 18, 84), (el, 19, 87), (conjunto, 20, 90), (de, 21, 99), (sistemas, 22, 102), (o, 23, 111), (combinación, 24, 113), (de, 25, 125), (algoritmos, 26, 128), (,, 27, 138), (cuyo, 28, 140), (
# , 29, 145), (propósito, 30, 146), (es, 31, 156), (crear, 32, 159), (máquinas, 33, 165), (que, 34, 174), (imitan, 35, 178), (la, 36, 185), (inteligencia, 37, 188), (humana, 38, 201), (para, 39, 208), (realizar, 40, 213), (
# , 41, 222), (tareas, 42, 223), (y, 43, 230), (pueden, 44, 232), (mejorar, 45, 239), (conforme, 46, 247), (la, 47, 256), (información, 48, 259), (que, 49, 271), (recopilan, 50, 275), (., 51, 284), (La, 52, 286), (inteligencia, 53, 289), (
# , 54, 302), (artificial, 55, 303), (no, 56, 314), (tiene, 57, 317), (como, 58, 323), (finalidad, 59, 328), (reemplazar, 60, 338), (a, 61, 349), (los, 62, 351), (humanos, 63, 355), (,, 64, 362), (sino, 65, 364), (mejorar, 66, 369), (
# , 67, 377), (significativamente, 68, 378), (las, 69, 397), (capacidades, 70, 401), (y, 71, 413), (contribuciones, 72, 415), (humanas, 73, 430), (., 74, 437), (Se, 75, 439), (hizo, 76, 442), (presente, 77, 447), (
# , 78, 456), (poco, 79, 457), (después, 80, 462), (de, 81, 470), (la, 82, 473), (Segunda, 83, 476), (Guerra, 84, 484), (Mundial, 85, 491), (,, 86, 498), (y, 87, 500), (el, 88, 502), (nombre, 89, 505), (lo, 90, 512), (acuñó, 91, 515), (en, 92, 521), (1956, 93, 524), (el, 94, 529), (
# , 95, 532), (informático, 96, 533), (John, 97, 545), (McCarthy, 98, 550), (,, 99, 558), (en, 100, 560), (la, 101, 563), (Conferencia, 102, 566), (de, 103, 578), (Dartmouth, 104, 581), (., 105, 590)]

# %% [markdown]
# #### Obteniendo la probabilidad del sentimiento

# %%
print([(word, word.sentiment) for word in text_doc])
# Out:
# [(La, 0.0), (inteligencia, 0.0), (artificial, 0.0), ((, 0.0), (IA, 0.0), (), 0.0), (,, 0.0), (en, 0.0), (el, 0.0), (contexto, 0.0), (de, 0.0), (las, 0.0), (ciencias, 0.0), (de, 0.0), (la, 0.0), (
# , 0.0), (computación, 0.0), (,, 0.0), (es, 0.0), (el, 0.0), (conjunto, 0.0), (de, 0.0), (sistemas, 0.0), (o, 0.0), (combinación, 0.0), (de, 0.0), (algoritmos, 0.0), (,, 0.0), (cuyo, 0.0), (
# , 0.0), (propósito, 0.0), (es, 0.0), (crear, 0.0), (máquinas, 0.0), (que, 0.0), (imitan, 0.0), (la, 0.0), (inteligencia, 0.0), (humana, 0.0), (para, 0.0), (realizar, 0.0), (
# , 0.0), (tareas, 0.0), (y, 0.0), (pueden, 0.0), (mejorar, 0.0), (conforme, 0.0), (la, 0.0), (información, 0.0), (que, 0.0), (recopilan, 0.0), (., 0.0), (La, 0.0), (inteligencia, 0.0), (
# , 0.0), (artificial, 0.0), (no, 0.0), (tiene, 0.0), (como, 0.0), (finalidad, 0.0), (reemplazar, 0.0), (a, 0.0), (los, 0.0), (humanos, 0.0), (,, 0.0), (sino, 0.0), (mejorar, 0.0), (
# , 0.0), (significativamente, 0.0), (las, 0.0), (capacidades, 0.0), (y, 0.0), (contribuciones, 0.0), (humanas, 0.0), (., 0.0), (Se, 0.0), (hizo, 0.0), (presente, 0.0), (
# , 0.0), (poco, 0.0), (después, 0.0), (de, 0.0), (la, 0.0), (Segunda, 0.0), (Guerra, 0.0), (Mundial, 0.0), (,, 0.0), (y, 0.0), (el, 0.0), (nombre, 0.0), (lo, 0.0), (acuñó, 0.0), (en, 0.0), (1956, 0.0), (el, 0.0), (
# , 0.0), (informático, 0.0), (John, 0.0), (McCarthy, 0.0), (,, 0.0), (en, 0.0), (la, 0.0), (Conferencia, 0.0), (de, 0.0), (Dartmouth, 0.0), (., 0.0)]

# %% [markdown]
# ### Extensiones
#
# Las extensiones me permite agregar, quitar, verificar o sobre escribir funciones o propiedades de un token.

# %% [markdown]
# #### Agregando funciones

# %%
# Importamos el objeto Token
from spacy.tokens import Token

# definimos uns función que me retorna True si es una preposición
def is_preposition(token: Token):
  # transforme el texto del token a lower case y verifico si está dentro de
  # la lista de presposiciones.
  # En este caso con el guión bajo "_" accedo a las extensiones
  return token.lower_ in token._.PREPOSITIONS

# Agregamos una propiedad al token que es una lista con todas la preposiciones
Token.set_extension("PREPOSITIONS", default=[
    "a", "ante", "bajo", "cabe", "con", "contra", "de", "desde", "durante",
    "en", "entre", "hacia", "hasta", "mediante", "para", "por", "según", "sin",
    "so", "sobre", "tras", "versus", "vía"])

# Agregmos una función que verifica si es una preposición
Token.set_extension("is_preposition",getter=is_preposition)

# %% [markdown]
# #### Utilizando extensiones

# %%
# t = nlp_es_sm(texto)
print(f"El token a verificar es ({text_doc[0]}): " , text_doc[0]._.is_preposition)
print(f"El token a verificar es ({text_doc[7]}): " , text_doc[7]._.is_preposition)
# Out:
# El token a verificar es (La):  False
# El token a verificar es (en):  True

# %% [markdown]
# #### Obteniendo funciones

# %%
# retorna una tupla con los valores de (default, method, getter, setter)
print("Está declarada la extesión 'is_preposition': ", Token.get_extension("is_preposition"))
print("Está declarada la extesión 'PREPOSITIONS': ", Token.get_extension("PREPOSITIONS"))
try:
  print("Está declarada la extesión 'is_prepositio' (NO EXISTE): ", Token.get_extension("is_prepositio"))
except KeyError:
  print("La documentación dice que tiene que lanzar una excepción")
# Out:
# Está declarada la extesión 'is_preposition':  (None, None, <function is_preposition at 0x7f93b7dfc820>, None)
# Está declarada la extesión 'PREPOSITIONS':  (['a', 'ante', 'bajo', 'cabe', 'con', 'contra', 'de', 'desde', 'durante', 'en', 'entre', 'hacia', 'hasta', 'mediante', 'para', 'por', 'según', 'sin', 'so', 'sobre', 'tras', 'versus', 'vía'], None, None, None)
# Está declarada la extesión 'is_prepositio' (NO EXISTE):  None

# %% [markdown]
# #### Verificando funciones

# %%
print("Está declarada la extesión 'is_preposition': ", Token.has_extension("is_preposition"))
print("Está declarada la extesión 'PREPOSITIONS': ", Token.has_extension("PREPOSITIONS"))
# Out:
# Está declarada la extesión 'is_preposition':  True
# Está declarada la extesión 'PREPOSITIONS':  True

# %% [markdown]
# #### Quitando fundiones

# %%
# retorna una tupla con los valores de (default, method, getter, setter)
# Quitamos las extensiones que definimos anteriormente
print("Quitando la extensión 'is_preposition': ", Token.remove_extension("is_preposition"))
print("Quitando la extensión 'PREPOSITIONS': ", Token.remove_extension("PREPOSITIONS"))
# Out:
# Quitando la extensión 'is_preposition':  (None, None, <function is_preposition at 0x7f93b7dfc820>, None)
# Quitando la extensión 'PREPOSITIONS':  (['a', 'ante', 'bajo', 'cabe', 'con', 'contra', 'de', 'desde', 'durante', 'en', 'entre', 'hacia', 'hasta', 'mediante', 'para', 'por', 'según', 'sin', 'so', 'sobre', 'tras', 'versus', 'vía'], None, None, None)

# %% [markdown]
# ### Funciones de un token
#
# Tener en cuenta que trabajan de acuerdo al `análisis sintáctico`.

# %%
print(text_doc)

print()
print("Obtiene los vecinos. Por defecto trae 1 vecino.")
print("Sentencia: text_doc[7].nbor(1)")
print(f"El token a verificar es ({text_doc[7]}): " , text_doc[7].nbor(1))

print()
print("Trae los vecinos a la izquierda.")
print("Sentencia: list(text_doc[12].lefts)")
print(f"El token a verificar es ({text_doc[12]}): " , list(text_doc[12].lefts))

print()
print("Trae los vecinos a la derecha.")
print("Sentencia: list(text_doc[1].rights)")
print(f"El token a verificar es ({text_doc[1]}): " , list(text_doc[1].rights))

print()
print("")
print("Trae cuantos vecinos tiene a la izquierda.")
print("Sentencia: text_doc[16].n_lefts")
print(f"El token a verificar es ({text_doc[16]}): " , text_doc[16].n_lefts)

print()
print("Trae cuantos vecinos tiene a la derecha.")
print("Sentencia: text_doc[9].n_rights")
print(f"El token a verificar es ({text_doc[9]}): " , text_doc[9].n_rights)

print()
print("Contiene una secuencia de token desencadenantes.")
print("Sentencia: list(text_doc[1].subtree)")
print(f"El token a verificar es ({text_doc[1]}): " , list(text_doc[1].subtree))

print()
print("Muestra las conjunciones")
print("Sentencia: list(text_doc[60].conjuncts)")
print(f"El token a verificar es ({text_doc[60]}): " , list(text_doc[60].conjuncts))

print()
print("Muestra el vector del token.")
print("Sentencia: text_doc[0].vector")
print(f"El token a verificar es ({text_doc[0]}): " , text_doc[0].vector)

print()
print("Calcula la normalización del vector.")
print("Sentencia: text_doc[0].vector_norm")
print(f"El token a verificar es ({text_doc[0]}): " , text_doc[0].vector_norm)
# Out:
# La inteligencia artificial (IA), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos, sino mejorar
# significativamente las capacidades y contribuciones humanas. Se hizo presente
# poco después de la Segunda Guerra Mundial, y el nombre lo acuñó en 1956 el
# informático John McCarthy, en la Conferencia de Dartmouth.
#
# Obtiene los vecinos. Por defecto trae 1 vecino.
# Sentencia: text_doc[7].nbor(1)
# El token a verificar es (en):  el
#
# Trae los vecinos a la izquierda.
# Sentencia: list(text_doc[12].lefts)
# El token a verificar es (ciencias):  [de, las]
#
# Trae los vecinos a la derecha.
# Sentencia: list(text_doc[1].rights)
# El token a verificar es (inteligencia):  [artificial, IA]
#
#
# Trae cuantos vecinos tiene a la izquierda.
# Sentencia: text_doc[16].n_lefts
# El token a verificar es (computación):  2
#
# Trae cuantos vecinos tiene a la derecha.
# Sentencia: text_doc[9].n_rights
# El token a verificar es (contexto):  2
#
# Contiene una secuencia de token desencadenantes.
# Sentencia: list(text_doc[1].subtree)
# El token a verificar es (inteligencia):  [La, inteligencia, artificial, (, IA, )]
#
# Muestra las conjunciones
# Sentencia: list(text_doc[60].conjuncts)
# El token a verificar es (reemplazar):  [mejorar]
#
# Muestra el vector del token.
# Sentencia: text_doc[0].vector
# El token a verificar es (La):  [ 1.1734607e+00 -3.7290132e-01  1.9309986e-01  4.2568316e+00
#  -3.4290749e-01  2.8853166e-01  2.6980360e+00  8.8591200e-01
#   6.8026370e-01  2.2371440e+00  7.8981400e-02 -1.0213494e-01
#   3.9081974e+00 -9.2605376e-01 -2.3082417e-01  1.7871287e+00
#   4.8426801e-01  9.0070558e-01 -9.2975932e-01  3.5877365e-01
#   1.9478009e+00  1.1029999e+00  1.9294351e-01 -1.9594579e+00
#   1.4898553e-03 -4.2027950e+00  2.2594249e+00  3.2846675e+00
#   2.3821030e+00  3.0622511e+00 -1.3810574e+00  2.8107166e+00
#   3.9030752e+00 -1.3785301e+00 -2.2816069e+00 -4.1330633e+00
#  -2.8463264e+00 -9.4830811e-02  1.5126359e-01  4.2407304e-01
#  -1.4330399e+00 -1.4617040e+00 -1.3048306e+00  4.8160019e+00
#  -1.5302501e+00  1.0400250e+00 -1.2284125e+00  2.4689672e+00
#  -1.3433316e+00  5.3911591e+00  1.6685503e+00 -1.8714619e-01
#   2.3163733e+00  5.0959188e-01 -2.7609542e-01  1.1436957e+00
#  -2.4795241e+00 -2.1736646e-01 -1.7351307e+00 -2.3163328e+00
#  -2.3363819e+00  1.1460102e+00 -2.1389894e+00  1.9277517e+00
#  -2.4123025e+00 -2.6846600e+00 -8.2855844e-01 -3.4966969e+00
#  -4.1529913e+00  1.8500960e-01 -1.2710552e+00  7.9647464e-01
#   1.1008793e+00 -1.6052964e+00 -3.8880687e+00 -1.5871337e-01
#  -1.7380607e+00 -1.4943949e+00  2.0991540e+00  4.7435861e+00
#   6.8145812e-02  7.0242578e-01 -1.7491291e+00  5.1878124e-01
#   3.6977186e+00 -1.3922944e+00 -6.2145925e-01 -2.0508659e+00
#  -1.5381199e+00 -1.3875189e+00  1.6703570e+00 -2.6662593e+00
#   1.4909052e+00 -1.0294418e+00 -1.1224413e+00 -7.5786972e-01]
#
# Calcula la normalización del vector.
# Sentencia: text_doc[0].vector_norm
# El token a verificar es (La):  20.499516

# %% [markdown]
# ## Span
#
# Cuando hacemos un slice de un Doc obtenemos un objeto Span que posee el conjunto de token del slice.
#
# El Span es un subconjunto de token.
#
# Poseen la particularidad de poseer extensiones y se trabajan de la misma forma que en los tokens pero con la particularidad que el objeto a importar para modificar es `from spacy.tokens import Span`.

# %%
spans = text_doc[5:65]

type(spans)
# Out:
# spacy.tokens.span.Span

# %% [markdown]
# ### Propiedades de un Span

# %% [markdown]
# #### Obteniendo el tensor del span

# %%
print("Span original (spans): \n", spans)
print()
print("Sentencia: spans.tensor")
print("Tiene el shape: ", spans.tensor.shape)
print("Posee 60 filas (una por cada token) y 96 columnas del modelo que lo genero.")
print("Obtenemos el siguiente resultado: \n", spans.tensor)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
# Sentencia: spans.tensor
# Tiene el shape:  (60, 96)
# Posee 60 filas (una por cada token) y 96 columnas del modelo que lo genero.
# Obtenemos el siguiente resultado:
#  [[ 3.4168372  -2.915241   -2.527809   ... -3.1648443  -2.8974512
#    0.13218635]
#  [-1.4443533  -0.23215675  1.2479451  ... -0.3245051  -1.7977653
#   -1.3231646 ]
#  [ 0.5696112   0.42312327 -1.0361539  ...  1.8937709   1.7449721
#    0.0448949 ]
#  ...
#  [ 3.392602   -1.9625684   0.7303077  ...  2.5844846   1.2904004
#    0.18194604]
#  [ 0.0162499   3.2155228  -2.5785184  ... -2.532539   -2.0466628
#   -1.6419266 ]
#  [-1.1618092   2.7418885  -2.1270742  ... -0.59063    -2.6591134
#   -1.1646391 ]]

# %% [markdown]
# #### Obteniendo el número del token de donde comienza

# %%
print("Span original (spans): \n", spans)
print()
print()
print("Sentencia: spans.start")
print("Obtenemos el siguiente resultado: ",spans.start)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
#
# Sentencia: spans.start
# Obtenemos el siguiente resultado:  5

# %% [markdown]
# #### Obteniendo el número del token de donde finaliza

# %%
print("Span original (spans): \n", spans)
print()
print()
print("Sentencia: spans.end")
print("Obtenemos el siguiente resultado: ",spans.end)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
#
# Sentencia: spans.end
# Obtenemos el siguiente resultado:  65

# %% [markdown]
# #### Obteniendo el número del caracter de donde comienza

# %%
print("Span original (spans): \n", spans)
print()
print()
print("Sentencia: spans.start_char")
print("Obtenemos el siguiente resultado: ",spans.start_char)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
#
# Sentencia: spans.start_char
# Obtenemos el siguiente resultado:  30

# %% [markdown]
# #### Obteniendo el número del caracter de donde finaliza

# %%
print("Span original (spans): \n", spans)
print()
print()
print("Sentencia: spans.end_char")
print("Obtenemos el siguiente resultado: ",spans.end_char)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
#
# Sentencia: spans.end_char
# Obtenemos el siguiente resultado:  363

# %% [markdown]
# #### Obteniendo el texto del span

# %%
print("Span original (spans): \n", spans)
print()
print("Sentencia: spans.text")
print("Obtenemos el siguiente resultado: \n",spans.text)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
# Sentencia: spans.text
# Obtenemos el siguiente resultado:
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,

# %% [markdown]
# #### Obteniendo el lemma

# %%
print("Span original (spans): \n", spans)
print()
print("Sentencia: spans.lemma_")
print("Obtenemos el siguiente resultado: \n",spans.lemma_)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
# Sentencia: spans.lemma_
# Obtenemos el siguiente resultado:
#  ), en el contexto de el ciencia de el
# computación, ser el conjunto de sistema o combinación de algoritmo, cuyo
# propósito ser crear máquina que imitar el inteligencia humano para realizar
# tarea y poder mejorar conforme el información que recopilir. el inteligencia
# artificial no tener como finalidad reemplazar a el humano,

# %% [markdown]
# #### Obteniendo la probabilidad del sentimiento

# %%
print("Span original (spans): \n", spans)
print()
print("Sentencia: spans.sentiment")
print("Obtenemos el siguiente resultado: ",spans.sentiment)
# Out:
# Span original (spans):
#  ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
# Sentencia: spans.sentiment
# Obtenemos el siguiente resultado:  0.0

# %% [markdown]
# ### Funciones de un span
#
# Tener en cuenta que trabajan de acuerdo al `análisis sintáctico`.
#
# Estás son las funciones principales.

# %%
print(spans)

print()
print("Obtiene los vecinos. Por defecto trae 1 vecino.")
print("Sentencia: spans[7].nbor(1)")
print(f"El token a verificar es ({spans[7]}): " , spans[7].nbor(1))

print()
print("Trae los vecinos a la izquierda.")
print("Sentencia: list(spans[7].lefts)")
print(f"El token a verificar es ({spans[7]}): " , list(spans[7].lefts))

print()
print("Trae los vecinos a la derecha.")
print("Sentencia: list(spans[7].rights)")
print(f"El token a verificar es ({spans[7]}): " , list(spans[7].rights))

print()
print("")
print("Trae cuantos vecinos tiene a la izquierda.")
print("Sentencia: spans[7].n_lefts")
print(f"El token a verificar es ({spans[7]}): " , spans[7].n_lefts)

print()
print("Trae cuantos vecinos tiene a la derecha.")
print("Sentencia: spans[7].n_rights")
print(f"El token a verificar es ({spans[7]}): " , spans[7].n_rights)

print()
print("Contiene una secuencia de token desencadenantes.")
print("Sentencia: list(spans[7].subtree)")
print(f"El token a verificar es ({spans[7]}): " , list(spans[7].subtree))

print()
print("Muestra las conjunciones")
print("Sentencia: list(spans[30].conjuncts)")
print(f"El token a verificar es ({spans[30]}): " , list(spans[30].conjuncts))

print()
print("Muestra el vector del token.")
print("Sentencia: spans[0].vector")
print(f"El token a verificar es '{spans[0]}': " , spans[0].vector)

print()
print("Calcula la normalización del vector.")
print("Sentencia: spans[0].vector_norm")
print(f"El token a verificar es '{spans[0]}': " , spans[0].vector_norm)
# Out:
# ), en el contexto de las ciencias de la
# computación, es el conjunto de sistemas o combinación de algoritmos, cuyo
# propósito es crear máquinas que imitan la inteligencia humana para realizar
# tareas y pueden mejorar conforme la información que recopilan. La inteligencia
# artificial no tiene como finalidad reemplazar a los humanos,
#
# Obtiene los vecinos. Por defecto trae 1 vecino.
# Sentencia: spans[7].nbor(1)
# El token a verificar es (ciencias):  de
#
# Trae los vecinos a la izquierda.
# Sentencia: list(spans[7].lefts)
# El token a verificar es (ciencias):  [de, las]
#
# Trae los vecinos a la derecha.
# Sentencia: list(spans[7].rights)
# El token a verificar es (ciencias):  [computación]
#
#
# Trae cuantos vecinos tiene a la izquierda.
# Sentencia: spans[7].n_lefts
# El token a verificar es (ciencias):  2
#
# Trae cuantos vecinos tiene a la derecha.
# Sentencia: spans[7].n_rights
# El token a verificar es (ciencias):  1
#
# Contiene una secuencia de token desencadenantes.
# Sentencia: list(spans[7].subtree)
# El token a verificar es (ciencias):  [de, las, ciencias, de, la,
# , computación]
#
# Muestra las conjunciones
# Sentencia: list(spans[30].conjuncts)
# El token a verificar es (imitan):  [mejorar]
#
# Muestra el vector del token.
# Sentencia: spans[0].vector
# El token a verificar es ')':  [ 3.4168372e+00 -2.9152410e+00 -2.5278089e+00 -2.9533689e+00
#   4.3101072e+00  4.7555590e+00 -8.1974679e-01 -2.2373703e+00
#  -1.4653611e+00 -3.0417165e-01 -5.1865739e-01 -1.7882054e+00
#   4.8791924e-01  2.4075522e+00 -1.2123959e+00 -1.5737718e+00
#  -3.1987662e+00 -2.5024381e+00 -1.6613394e+00 -2.9198952e+00
#   7.2515512e-01 -6.6623724e-01  2.0284672e+00  1.2674325e+00
#   5.2929938e-02  5.7207236e+00 -1.9109350e+00 -2.7132328e+00
#  -2.7568812e+00 -6.5758073e-01  3.3043377e+00  4.5869069e+00
#   3.5524259e+00 -1.2969091e+00  1.9001962e+00 -1.9193299e+00
#   5.1219530e+00  1.4215550e+00 -3.1401515e-01  5.9781325e-01
#   2.8837183e-01 -1.4031487e+00  3.2097349e+00  2.6395969e+00
#   3.9881885e-02 -8.4308857e-01  6.3341489e+00  4.1950738e-01
#   5.4467487e-01  9.6713835e-01 -6.3142538e-01  2.6948979e+00
#   3.1814518e+00  3.9375243e-01 -1.8337328e+00 -3.9381366e+00
#   3.1747561e+00 -2.1966546e+00  1.4299014e+00 -1.0847857e+00
#  -5.8195662e-01 -2.2652369e+00  5.6372046e-02  3.5540318e-01
#  -4.5911531e+00  1.2056537e+00 -1.1876008e-01  1.4515814e+00
#   2.6851821e+00 -1.5557227e+00 -6.3029510e-01 -2.6384497e+00
#   2.1547570e+00 -2.2167332e+00 -1.6167824e+00  7.2437847e-01
#  -3.9643693e+00 -1.1056278e+00 -2.6558781e+00  7.2388482e-01
#  -2.5719801e-01 -5.3850210e-01 -2.2023749e+00  3.1285584e-03
#  -2.8895323e+00  2.0789358e-01  2.7644134e-01  1.5458137e+00
#   1.9184759e+00  1.6028565e-01  1.3981481e+00  3.3049664e+00
#   1.4777675e+00 -3.1648443e+00 -2.8974512e+00  1.3218635e-01]
#
# Calcula la normalización del vector.
# Sentencia: spans[0].vector_norm
# El token a verificar es ')':  22.81601

# %% [markdown]
# ## Stopwords
#
#
# Las stop words, son palabras que se consideran muy comunes en un idioma en particular y, por lo tanto, no aportan un valor semántico significativo a una frase o texto. Ejemplos comunes de stop words en inglés son "de", "la", "que", "con", "muy", "ante", "eso", entre otros.
#
# En el procesamiento de lenguaje natural, las stop words se eliminan o se ignoran para evitar que afecten el resultado de la búsqueda o el análisis. La eliminación de stop words puede ayudar a reducir la dimensionalidad del texto y mejorar la eficiencia de los algoritmos de búsqueda, ya que estas palabras no proporcionan información útil para la clasificación o la recuperación de información.
#
# Sin embargo, la eliminación de stop words también puede tener un impacto negativo en el resultado final, especialmente si se trata de un texto corto o si las stop words son importantes en el contexto específico del texto. Por esta razón, en algunos casos puede ser necesario ajustar el conjunto de stop words o no eliminarlas por completo.
#
# Es importante destacar que el conjunto de stop words varía según el idioma y el contexto, por lo que es necesario elegir cuidadosamente qué palabras se eliminan o se mantienen en cada caso.

# %%
stopwords = nlp_es_sm.Defaults.stop_words
print("En nltk teníamos: 313")
print("Existen: ", len(stopwords))
print("Estos son los stop words en español:\n", sorted(stopwords))
# Out:
# En nltk teníamos: 313
# Existen:  521
# Estos son los stop words en español:
#  ['a', 'acuerdo', 'adelante', 'ademas', 'además', 'afirmó', 'agregó', 'ahi', 'ahora', 'ahí', 'al', 'algo', 'alguna', 'algunas', 'alguno', 'algunos', 'algún', 'alli', 'allí', 'alrededor', 'ambos', 'ante', 'anterior', 'antes', 'apenas', 'aproximadamente', 'aquel', 'aquella', 'aquellas', 'aquello', 'aquellos', 'aqui', 'aquél', 'aquélla', 'aquéllas', 'aquéllos', 'aquí', 'arriba', 'aseguró', 'asi', 'así', 'atras', 'aun', 'aunque', 'añadió', 'aún', 'bajo', 'bastante', 'bien', 'breve', 'buen', 'buena', 'buenas', 'bueno', 'buenos', 'cada', 'casi', 'cierta', 'ciertas', 'cierto', 'ciertos', 'cinco', 'claro', 'comentó', 'como', 'con', 'conmigo', 'conocer', 'conseguimos', 'conseguir', 'considera', 'consideró', 'consigo', 'consigue', 'consiguen', 'consigues', 'contigo', 'contra', 'creo', 'cual', 'cuales', 'cualquier', 'cuando', 'cuanta', 'cuantas', 'cuanto', 'cuantos', 'cuatro', 'cuenta', 'cuál', 'cuáles', 'cuándo', 'cuánta', 'cuántas', 'cuánto', 'cuántos', 'cómo', 'da', 'dado', 'dan', 'dar', 'de', 'debajo', 'debe', 'deben', 'debido', 'decir', 'dejó', 'del', 'delante', 'demasiado', 'demás', 'dentro', 'deprisa', 'desde', 'despacio', 'despues', 'después', 'detras', 'detrás', 'dia', 'dias', 'dice', 'dicen', 'dicho', 'dieron', 'diez', 'diferente', 'diferentes', 'dijeron', 'dijo', 'dio', 'doce', 'donde', 'dos', 'durante', 'día', 'días', 'dónde', 'e', 'el', 'ella', 'ellas', 'ello', 'ellos', 'embargo', 'en', 'encima', 'encuentra', 'enfrente', 'enseguida', 'entonces', 'entre', 'era', 'eramos', 'eran', 'eras', 'eres', 'es', 'esa', 'esas', 'ese', 'eso', 'esos', 'esta', 'estaba', 'estaban', 'estado', 'estados', 'estais', 'estamos', 'estan', 'estar', 'estará', 'estas', 'este', 'esto', 'estos', 'estoy', 'estuvo', 'está', 'están', 'excepto', 'existe', 'existen', 'explicó', 'expresó', 'fin', 'final', 'fue', 'fuera', 'fueron', 'fui', 'fuimos', 'gran', 'grande', 'grandes', 'ha', 'haber', 'habia', 'habla', 'hablan', 'habrá', 'había', 'habían', 'hace', 'haceis', 'hacemos', 'hacen', 'hacer', 'hacerlo', 'haces', 'hacia', 'haciendo', 'hago', 'han', 'hasta', 'hay', 'haya', 'he', 'hecho', 'hemos', 'hicieron', 'hizo', 'hoy', 'hubo', 'igual', 'incluso', 'indicó', 'informo', 'informó', 'ir', 'junto', 'la', 'lado', 'largo', 'las', 'le', 'les', 'llegó', 'lleva', 'llevar', 'lo', 'los', 'luego', 'mal', 'manera', 'manifestó', 'mas', 'mayor', 'me', 'mediante', 'medio', 'mejor', 'mencionó', 'menos', 'menudo', 'mi', 'mia', 'mias', 'mientras', 'mio', 'mios', 'mis', 'misma', 'mismas', 'mismo', 'mismos', 'modo', 'mucha', 'muchas', 'mucho', 'muchos', 'muy', 'más', 'mí', 'mía', 'mías', 'mío', 'míos', 'nada', 'nadie', 'ni', 'ninguna', 'ningunas', 'ninguno', 'ningunos', 'ningún', 'no', 'nos', 'nosotras', 'nosotros', 'nuestra', 'nuestras', 'nuestro', 'nuestros', 'nueva', 'nuevas', 'nueve', 'nuevo', 'nuevos', 'nunca', 'o', 'ocho', 'once', 'os', 'otra', 'otras', 'otro', 'otros', 'para', 'parece', 'parte', 'partir', 'pasada', 'pasado', 'paìs', 'peor', 'pero', 'pesar', 'poca', 'pocas', 'poco', 'pocos', 'podeis', 'podemos', 'poder', 'podria', 'podriais', 'podriamos', 'podrian', 'podrias', 'podrá', 'podrán', 'podría', 'podrían', 'poner', 'por', 'porque', 'posible', 'primer', 'primera', 'primero', 'primeros', 'pronto', 'propia', 'propias', 'propio', 'propios', 'proximo', 'próximo', 'próximos', 'pudo', 'pueda', 'puede', 'pueden', 'puedo', 'pues', 'qeu', 'que', 'quedó', 'queremos', 'quien', 'quienes', 'quiere', 'quiza', 'quizas', 'quizá', 'quizás', 'quién', 'quiénes', 'qué', 'realizado', 'realizar', 'realizó', 'repente', 'respecto', 'sabe', 'sabeis', 'sabemos', 'saben', 'saber', 'sabes', 'salvo', 'se', 'sea', 'sean', 'segun', 'segunda', 'segundo', 'según', 'seis', 'ser', 'sera', 'será', 'serán', 'sería', 'señaló', 'si', 'sido', 'siempre', 'siendo', 'siete', 'sigue', 'siguiente', 'sin', 'sino', 'sobre', 'sois', 'sola', 'solamente', 'solas', 'solo', 'solos', 'somos', 'son', 'soy', 'su', 'supuesto', 'sus', 'suya', 'suyas', 'suyo', 'suyos', 'sé', 'sí', 'sólo', 'tal', 'tambien', 'también', 'tamp ...

# %%
# vamos a limpiar el texto que venimos trabajando
# verificamos si la palabra no esta dentro de la lista de stopwords.
# print(" ".join([word for word in text_doc if word not in stopwords]))
print(" ".join([str(word) for word in text_doc  if str(word).lower() not in stopwords]))
# Out:
# inteligencia artificial ( IA ) , contexto ciencias
#  computación , conjunto sistemas combinación algoritmos , cuyo
#  propósito crear máquinas imitan inteligencia humana
#  tareas mejorar conforme información recopilan . inteligencia
#  artificial finalidad reemplazar humanos , mejorar
#  significativamente capacidades contribuciones humanas . presente
#  Guerra Mundial , nombre acuñó 1956
#  informático John McCarthy , Conferencia Dartmouth .

# %% [markdown]
# ## Objeto Matcher
#
# Basándose en expresiones regulares, me permite encontrar palabras y frases a travez de los atributos de un token. Las reglas pueden referirse a anotaciones de tokens (como el texto o las etiquetas), así como a atributos léxicos como Token.is_punct.
#
# | Forma | Tipo | Descripción |
# | --- | --- | --- |
# | ORTH | str | El texto literal exacto de un token. |
# | TEXT | str | El texto literal exacto de un token. |
# | NORM | str | La forma normalizada del texto del token. |
# | LOWER | str | La forma minúscula del texto del token. |
# | LENGTH | int | La longitud del texto. |
# | IS_ALPHA, IS_ASCII, IS_DIGIT | bool | El texto simbólico consta de caracteres alfabéticos, caracteres ASCII, dígitos. |
# | IS_LOWER, IS_UPPER, IS_TITLE | bool | El texto de la ficha está en minúsculas, mayúsculas, título. |
# | IS_PUNCT, IS_SPACE, IS_STOP | bool | La ficha contiene signos de puntuación, espacios en blanco o una palabra de parada. |
# | IS_SENT_START | bool | La entrada es el principio de la frase. |
# | LIKE_NUM, LIKE_URL, LIKE_EMAIL | bool | El texto del token se parece a un número, URL, email. |
# | SPACY | bool | El token tiene un espacio al final. |
# | POS, TAG, MORPH, DEP, LEMMA, SHAPE | str | Etiqueta de pos simple y extendida, análisis morfológico, etiqueta de dependencia, lema, forma. |
# | ENT_TYPE | str | La etiqueta de entidad del token. |
# | ENT_IOB | str | La parte IOB de la etiqueta de entidad del token. |
# | ENT_ID | str | El ID de entidad de la ficha (ent_id). |
# | ENT_KB_ID | str | El ID de la base de conocimiento de la entidad del token (ent_kb_id). |
# | OP | str | Operador o cuantificador para determinar la frecuencia de coincidencia con un patrón de token. |

# %%
words_ = [word for word in text_doc]
pos_ = [word.pos for word in text_doc]
lemmas_ = [word.lemma_ for word in text_doc]
# !pip install tabulate
from tabulate import tabulate
print(tabulate([(word, word.pos_, word.lemma_) for word in text_doc], headers=["PALABRA", "POS", "LEMMA"]))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (0.8.10)
# PALABRA             POS    LEMMA
# ------------------  -----  ------------------
# La                  DET    el
# inteligencia        NOUN   inteligencia
# artificial          ADJ    artificial
# (                   PUNCT  (
# IA                  PROPN  IA
# )                   PUNCT  )
# ,                   PUNCT  ,
# en                  ADP    en
# el                  DET    el
# contexto            NOUN   contexto
# de                  ADP    de
# las                 DET    el
# ciencias            NOUN   ciencia
# de                  ADP    de
# la                  DET    el
#                     SPACE
# computación         NOUN   computación
# ,                   PUNCT  ,
# es                  AUX    ser
# el                  DET    el
# conjunto            NOUN   conjunto
# de                  ADP    de
# sistemas            NOUN   sistema
# o                   CCONJ  o
# combinación         NOUN   combinación
# de                  ADP    de
# algoritmos          NOUN   algoritmo
# ,                   PUNCT  ,
# cuyo                PRON   cuyo
#                     SPACE
# propósito           NOUN   propósito
# es                  AUX    ser
# crear               VERB   crear
# máquinas            NOUN   máquina
# que                 PRON   que
# imitan              VERB   imitar
# la                  DET    el
# inteligencia        NOUN   inteligencia
# humana              ADJ    humano
# para                ADP    para
# realizar            VERB   realizar
#                     SPACE
# tareas              NOUN   tarea
# y                   CCONJ  y
# pueden              AUX    poder
# mejorar             VERB   mejorar
# conforme            ADP    conforme
# la                  DET    el
# información         NOUN   información
# que                 PRON   que
# recopilan           VERB   recopilir
# .                   PUNCT  .
# La                  DET    el
# inteligencia        NOUN   inteligencia
#                     SPACE
# artificial          ADJ    artificial
# no                  ADV    no
# tiene               VERB   tener
# como                SCONJ  como
# finalidad           NOUN   finalidad
# reemplazar          VERB   reemplazar
# a                   ADP    a
# los                 DET    el
# humanos             NOUN   humano
# ,                   PUNCT  ,
# sino                CCONJ  sino
# mejorar             VERB   mejorar
#                     SPACE
# significativamente  ADV    significativamente
# las                 DET    el
# capacidades         NOUN   capacidad
# y                   CCONJ  y
# contribuciones      NOUN   contribución
# humanas             ADJ    humano
# .                   PUNCT  .
# Se                  PRON   él
# hizo                VERB   hacer
# presente            ADJ    presente
#                     SPACE
# poco                ADV    poco
# después             ADV    después
# de                  ADP    de
# la                  DET    el
# Segunda             PROPN  Segunda
# Guerra              PROPN  Guerra
# Mundial             PROPN  Mundial
# ,                   PUNCT  ,
# y                   CCONJ  y
# el                  DET    el
# nombre              NOUN   nombre
# lo                  PRON   él
# acuñó               VERB   acuñó
# en                  ADP    en
# 1956                NOUN   1956
# el                  DET    el
#                     SPACE
# informático         NOUN   informático
# John                PROPN  John
# McCarthy            PROPN  McCarthy
# ,                   PUNCT  ,
# en                  ADP    en
# la                  DET    el
# Conferencia         PROPN  Conferencia
# de                  ADP    de
# Dartmouth           PROPN  Dartmouth
# .                   PUNCT  .

# %%
from spacy.matcher import Matcher
# creamos un matcher con el vocabulario del idioma
matcher = Matcher(nlp_es_sm.vocab)
# creamos la matcher de la expresión regular, en este caso
# buscamos el lemma "ser"
pattern = [{"LEMMA": "ser"}]
#agregamos el patron
matcher.add("lemma_ser", [pattern])
# ejecutamos el matcher
matches = matcher(text_doc)

for match_ in matches:
  print(f"La palabra correspondiente es '{text_doc[match_[1]:match_[2]]}'")
  print(f"El texto alrededor de la palabra es:\n", text_doc[match_[1]-5:match_[2]+5])
  print()
# Out:
# La palabra correspondiente es 'es'
# El texto alrededor de la palabra es:
#  de la
# computación, es el conjunto de sistemas o
#
# La palabra correspondiente es 'es'
# El texto alrededor de la palabra es:
#  algoritmos, cuyo
# propósito es crear máquinas que imitan la

# %%
# creamos un matcher con el vocabulario del idioma
matcher = Matcher(nlp_es_sm.vocab)
# creamos la matcher de la expresión regular, en este caso
# buscamos el pos "sustantivo+conjunción+sustantivo"
pattern = [{"POS": "NOUN"},
           {"POS": "CCONJ"},
           {"POS": "NOUN"},]
#agregamos el patron
matcher.add("noun_cconj_noun", [pattern])
# ejecutamos el matcher
matches = matcher(text_doc)

for match_ in matches:
  print(f"La palabra correspondiente es '{text_doc[match_[1]:match_[2]]}'")
  print(f"El texto alrededor de la palabra es:\n", text_doc[match_[1]-5:match_[2]+5])
  print()
# Out:
# La palabra correspondiente es 'sistemas o combinación'
# El texto alrededor de la palabra es:
#  , es el conjunto de sistemas o combinación de algoritmos, cuyo
#
#
# La palabra correspondiente es 'capacidades y contribuciones'
# El texto alrededor de la palabra es:
#  sino mejorar
# significativamente las capacidades y contribuciones humanas. Se hizo presente

# %%
# creamos un matcher con el vocabulario del idioma
matcher = Matcher(nlp_es_sm.vocab)
# creamos la matcher de la expresión regular, en este caso
# buscamos la palabra "el"+"sustantivo"
pattern = [
    {"LOWER": "el"},
    {"POS": "NOUN"},
           ]
#agregamos el patron
matcher.add("el_noum", [pattern])
# ejecutamos el matcher
matches = matcher(text_doc)

for match_ in matches:
  print(f"La palabra correspondiente es '{text_doc[match_[1]:match_[2]]}'")
  print(f"El texto alrededor de la palabra es:\n", text_doc[match_[1]-5:match_[2]+5])
  print()
# Out:
# La palabra correspondiente es '1956'
# El texto alrededor de la palabra es:
#  el nombre lo acuñó en 1956 el
# informático John McCarthy

# %%
# creamos un matcher con el vocabulario del idioma
matcher = Matcher(nlp_es_sm.vocab)
# creamos la matcher de la expresión regular, en este caso
# buscamos algo que tenga la forma de 4 números
pattern = [{"SHAPE": "dddd"}]
#agregamos el patron
matcher.add("shape_dddd", [pattern])
# ejecutamos el matcher
matches = matcher(text_doc)

for match_ in matches:
  print(f"La palabra correspondiente es '{text_doc[match_[1]:match_[2]]}'")
  print(f"El texto alrededor de la palabra es:\n", text_doc[match_[1]-5:match_[2]+5])
  print()

# %% [markdown]
# ## Otros objetos
#
# Esiten otros objetos que me permite cambiar el flujo de trabajo de acuerdo a nuevas reglas impuestras por el usuario.
#
# Por ejemplo, escribir nuevos lemmas o entidades de reconocimiento o cambios morfológicos en el reconocimiento de la oración, etc.
#
# [Ver la documentación](https://spacy.io/api)
