# %% [markdown]
# <a href="https://colab.research.google.com/github/Danangellotti/Ciencia_de_Datos_UGR_24/blob/main/u4_agrupar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Unidad 4 - Agrupar
#
# Basada en los los libros:
# - Capitulo 10 del libro Python for Data Analysis
# - Capitulo 3 del libro Python Data Science Handbook

# %% [markdown]
# # Inicialización

# %%
# import paquetes
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# options numpy
np.random.seed(12345)

pd.set_option('display.min_rows', 30)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Datos de premios nobel: https://www.kaggle.com/datasets/imdevskp/nobel-prize/

# %%
nobel_complete = pd.read_csv("nobel_prize_v9.csv")
nobel_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   awardYear                   950 non-null    int64
#  1   category                    950 non-null    object
#  2   categoryFullName            950 non-null    object
#  3   sortOrder                   950 non-null    int64
#  4   portion                     950 non-null    object
#  5   prizeAmount                 950 non-null    int64
#  6   prizeAmountAdjusted         950 non-null    int64
#  7   dateAwarded                 533 non-null    object
#  8   prizeStatus                 950 non-null    object
#  9   motivation                  950 non-null    object
#  10  categoryTopMotivation       20 non-null     object
#  11  award_link                  950 non-null    object
#  12  id                          950 non-null    int64
#  13  name                        950 non-null    object
#  14  knownName                   923 non-null    object
#  15  givenName                   923 non-null    object
#  16  familyName                  921 non-null    object
#  17  fullName                    923 non-null    object
#  18  penName                     11 non-null     object
#  19  gender                      923 non-null    object
#  20  laureate_link               950 non-null    object
#  21  birth_date                  923 non-null    object
#  22  birth_city                  922 non-null    object
#  23  birth_cityNow               922 non-null    object
#  24  birth_continent             923 non-null    object
#  25  birth_country               923 non-null    object
#  26  birth_countryNow            923 non-null    object
#  27  birth_locationString        923 non-null    object
#  28  death_date                  630 non-null    object
#  29  death_city                  611 non-null    object
#  30  death_cityNow               611 non-null    object
#  31  death_continent             617 non-null    object
#  32  death_country               617 non-null    object
#  33  death_countryNow            617 non-null    object
#  34  death_locationString        618 non-null    object
#  35  orgName                     27 non-null     object
#  36  nativeName                  27 non-null     object
#  37  acronym                     11 non-null     object
#  38  org_founded_date            26 non-null     object
#  39  org_founded_city            22 non-null     object
#  40  org_founded_cityNow         22 non-null     object
#  41  org_founded_continent       24 non-null     object
#  42  org_founded_country         24 non-null     object
#  43  org_founded_countryNow      24 non-null     object
#  44  org_founded_locationString  24 non-null     object
#  45  ind_or_org                  950 non-null    object
#  46  residence_1                 219 non-null    object
#  47  residence_2                 2 non-null      object
#  48  affiliation_1               697 non-null    object
#  49  affiliation_2               67 non-null     object
#  50  affiliation_3               2 non-null      object
#  51  affiliation_4               1 non-null      object
# dtypes: int64(5), object(47)
# memory usage: 386.1+ KB

# %%
nobel_complete
# Out:
#      awardYear                category  \
# 0         2001       Economic Sciences
# 1         1975                 Physics
# 2         2004               Chemistry
# 3         1982               Chemistry
# 4         1979                 Physics
# 5         2019       Economic Sciences
# 6         2019                   Peace
# 7         2009               Chemistry
# 8         2011                 Physics
# 9         1939               Chemistry
# 10        1905               Chemistry
# 11        1928               Chemistry
# 12        1980                   Peace
# 13        1999               Chemistry
# 14        2010               Chemistry
# ..         ...                     ...
# 935       1994                   Peace
# 936       1968              Literature
# 937       1994                   Peace
# 938       2008                 Physics
# 939       2016  Physiology or Medicine
# 940       1986               Chemistry
# 941       2005               Chemistry
# 942       2000                 Physics
# 943       1980               Chemistry
# 944       1944                   Peace
# 945       1972                 Physics
# 946       1954               Chemistry
# 947       1911               Chemistry
# 948       1981                   Peace
# 949       1963                   Peace
#
#                                       categoryFullName  sortOrder portion  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 1                           The Nobel Prize in Physics          1     1/3
# 2                         The Nobel Prize in Chemistry          1     1/3
# 3                         The Nobel Prize in Chemistry          1       1
# 4                           The Nobel Prize in Physics          2     1/3
# 5    The Sveriges Riksbank Prize in Economic Scienc...          1     1/3
# 6                                The Nobel Peace Prize          1       1
# 7                         The Nobel Prize in Chemistry          3     1/3
# 8                           The Nobel Prize in Physics          3     1/4
# 9                         The Nobel Prize in Chemistry          1     1/2
# 10                        The Nobel Prize in Chemistry          1       1
# 11                        The Nobel Prize in Chemistry          1       1
# 12                               The Nobel Peace Prize          1       1
# 13                        The Nobel Prize in Chemistry          1       1
# 14                        The Nobel Prize in Chemistry          3     1/3
# ..                                                 ...        ...     ...
# 935                              The Nobel Peace Prize          1     1/3
# 936                     The Nobel Prize in  Literature          1       1
# 937                              The Nobel Peace Prize          3     1/3
# 938                         The Nobel Prize in Physics          1     1/2
# 939          The Nobel Prize in Physiology or Medicine          1       1
# 940                       The Nobel Prize in Chemistry          2     1/3
# 941                       The Nobel Prize in Chemistry          1     1/3
# 942                         The Nobel Prize in Physics          1     1/4
# 943                       The Nobel Prize in Chemistry          3     1/4
# 944                              The Nobel Peace Prize          1       1
# 945                         The Nobel Prize in Physics          1     1/3
# 946                       The Nobel Prize in Chemistry          1       1
# 947                       The Nobel Prize in Chemistry          1       1
# 948                              The Nobel Peace Prize          1       1
# 949                              The Nobel Peace Prize          1     1/2
#
#      prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0       10000000             12295082  2001-10-10    received
# 1         630000              3404179  1975-10-17    received
# 2       10000000             11762861  2004-10-06    received
# 3        1150000              3102518  1982-10-18    received
# 4         800000              2988048  1979-10-15    received
# 5        9000000              9000000  2019-10-14    received
# 6        9000000              9000000  2019-10-11    received
# 7       10000000             10958504  2009-10-07    received
# 8       10000000             10545557  2011-10-04    received
# 9         148822              4227898         NaN    received
# 10        138089              7615202         NaN    received
# 11        156939              4458494         NaN    received
# 12        880000              2889667  1980-10-27    received
# 13       7900000             10049186  1999-10-12    received
# 14      10000000             10819388  2010-10-06    received
# ..           ...                  ...         ...         ...
# 935      7000000              9249471  1994-10-14    received
# 936       350000              3052326         NaN    received
# 937      7000000              9249471  1994-10-14    received
# 938     10000000             10926573  2008-10-07    received
# 939      8000000              8301051         NaN    received
# 940      2000000              4098361  1986-10-15    received
# 941     10000000             11711430  2005-10-05    received
# 942      9000000             11333109  2000-10-10    received
# 943       880000              2889667  1980-10-14    received
# 944       121841              2510460  1945-11-12    received
# 945       480000              3345725         NaN    received
# 946       181647              2640218         NaN    received
# 947       140695              7327865         NaN    received
# 948      1000000              2929688  1981-10-14    received
# 949       265000              2839286  1963-10-10    received
#
#                                             motivation  ...  \
# 0    for their analyses of markets with asymmetric ...  ...
# 1    for the discovery of the connection between co...  ...
# 2    for the discovery of ubiquitin-mediated protei...  ...
# 3    for his development of crystallographic electr...  ...
# 4    for their contributions to the theory of the u...  ...
# 5    for their experimental approach to alleviating...  ...
# 6    for his efforts to achieve peace and internati...  ...
# 7    for studies of the structure and function of t...  ...
# 8    for the discovery of the accelerating expansio...  ...
# 9                         for his work on sex hormones  ...
# 10   in recognition of his services in the advancem...  ...
# 11   for the services rendered through his research...  ...
# 12   for being a source of inspiration to repressed...  ...
# 13   for his studies of the transition states of ch...  ...
# 14   for palladium-catalyzed cross couplings in org...  ...
# ..                                                 ...  ...
# 935  for their efforts to create peace in the Middl...  ...
# 936  for his narrative mastery, which with great se...  ...
# 937  for their efforts to create peace in the Middl...  ...
# 938  for the discovery of the mechanism of spontane...  ...
# 939    for his discoveries of mechanisms for autophagy  ...
# 940  for their contributions concerning the dynamic...  ...
# 941  for the development of the metathesis method i...  ...
# 942  for developing semiconductor heterostructures ...  ...
# 943  for their contributions concerning the determi...  ...
# 944  for the great work it has performed during the...  ...
# 945  for their jointly developed theory of supercon...  ...
# 946  for his research into the nature of the chemic...  ...
# 947  in recognition of her services to the advancem...  ...
# 948   for promoting the fundamental rights of refugees  ...
# 949  for promoting the principles of the Geneva Con...  ...
#
#     org_founded_country org_founded_countryNow  org_founded_locationString  \
# 0                   NaN                    NaN                         NaN
# 1                   NaN                    NaN                         NaN
# 2                   NaN                    NaN                         NaN
# 3                   NaN                    NaN                         NaN
# 4                   NaN                    NaN                         NaN
# 5                   NaN                    NaN                         NaN
# 6                   NaN                    NaN                         NaN
# 7                   NaN                    NaN                         NaN
# 8                   NaN                    NaN                         NaN
# 9                   NaN                    NaN                         NaN
# 10                  NaN                    NaN                         NaN
# 11                  NaN                    NaN                         NaN
# 12                  NaN                    NaN                         NaN
# 13                  NaN                    NaN                         NaN
# 14                  NaN                    NaN                         NaN
# ..                  ...                    ...                         ...
# 935                 NaN                    NaN                         NaN
# 936                 NaN                    NaN                         NaN
# 937                 NaN                    NaN                         NaN
# 938                 NaN                    NaN                         NaN
# 939                 NaN                    NaN                         NaN
# 940                 NaN                    NaN                         NaN
# 941                 NaN                    NaN                         NaN
# 942                 NaN                    NaN                         NaN
# 943                 NaN                    NaN                         NaN
# 944         Switzerland            Switzerland         Geneva, Switzerland
# 945                 NaN                    NaN                         NaN
# 946                 NaN                    NaN                         NaN
# 947                 NaN                    NaN                         NaN
# 948         Switzerland            Switzerland         Geneva, Switzerland
# 949         Switzerland            Switzerland         Geneva, Switzerland
#
#        ind_or_org residence_1 residence_2  \
# 0      Individual         NaN         NaN
# 1      Individual         NaN         NaN
# 2      Individual         NaN         NaN
# 3      Individual         NaN         NaN
# 4      Individual         NaN         NaN
# 5      Individual         NaN         NaN
# 6      Individual         NaN         NaN
# 7      Individual         NaN         NaN
# 8      Individual         NaN         NaN
# 9      Individual         NaN         NaN
# 10     Individual         NaN         NaN
# 11     Individual         NaN         NaN
# 12     Individual   Argentina         NaN
# 13     Individual         NaN         NaN
# 14     Individual         NaN         NaN
# ..            ...         ...         ...
# 935    Individual   Palestine         NaN
# 936    Individual       Japan         NaN
# 937    Individual      Israel         NaN
# 938    Individual         NaN         NaN
# 939    Individual         NaN         NaN
# 940    Individual         NaN         NaN
# 941    Individual         NaN         NaN
# 942    Individual         NaN         NaN
# 943    Individual         NaN         NaN
# 944  Organization         NaN         NaN
# 945    Individual         NaN         NaN
# 946    Individual         NaN         NaN
# 947    Individual         NaN         NaN
# 948  Organization         NaN         NaN
# 949  Organization         NaN         NaN
#
#                                          affiliation_1  \
# 0               Stanford University, Stanford, CA, USA
# 1            Niels Bohr Institute, Copenhagen, Denmark
# 2    Technion - Israel Institute of Technology, Hai...
# 3    MRC Laboratory of Molecular Biology, Cambridge...
# 4    International Centre for Theoretical Physics, ...
# 5    Massachusetts Institute of Technology (MIT), C...
# 6                                                  NaN
# 7       Weizmann Institute of Science, Rehovot, Israel
# 8         Johns Hopkins University, Baltimore, MD, USA
# 9    Kaiser-Wilhelm-Institut (now Max-Planck-Instit...
# 10                  Munich University, Munich, Germany
# 11           Goettingen University, Göttingen, Germany
# 12                                                 NaN
# 13   California Institute of Technology (Caltech), ...
# 14                 Hokkaido University, Sapporo, Japan
# ..                                                 ...
# 935                                                NaN
# 936                                                NaN
# 937                                                NaN
# 938  Enrico Fermi Institute, University of Chicago,...
# 939        Tokyo Institute of Technology, Tokyo, Japan
# 940        University of California, Berkeley, CA, USA
# 941  Institut Français du Pétrole, Rueil-Malmaison,...
# 942  A.F. Ioffe Physico-Technical Institute, St. Pe...
# 943  MRC Laboratory of Molecular Biology, Cambridge...
# 944                                                NaN
# 945            University of Illinois, Urbana, IL, USA
# 946  California Institute of Technology (Caltech), ...
# 947                 Sorbonne University, Paris, France
# 948                                                NaN
# 949                                                NaN
#
#                                          affiliation_2 affiliation_3  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4             Imperial College, London, United Kingdom           NaN
# 5                                                  NaN           NaN
# 6                                                  NaN           NaN
# 7                                                  NaN           NaN
# 8    Space Telescope Science Institute, Baltimore, ...           NaN
# 9                   Berlin University, Berlin, Germany           NaN
# 10                                                 NaN           NaN
# 11                                                 NaN           NaN
# 12                                                 NaN           NaN
# 13                                                 NaN           NaN
# 14                                                 NaN           NaN
# ..                                                 ...           ...
# 935                                                NaN           NaN
# 936                                                NaN           NaN
# 937                                                NaN           NaN
# 938                                                NaN           NaN
# 939                                                NaN           NaN
# 940                                                NaN           NaN
# 941                                                NaN           NaN
# 942                                                NaN           NaN
# 943                                                NaN           NaN
# 944                                                NaN           NaN
# 945                                                NaN           NaN
# 946                                                NaN           NaN
# 947                                                NaN           NaN
# 948                                                NaN           NaN
# 949                                                NaN           NaN
#
#     affiliation_4
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# ..            ...
# 935           NaN
# 936           NaN
# 937           NaN
# 938           NaN
# 939           NaN
# 940           NaN
# 941           NaN
# 942           NaN
# 943           NaN
# 944           NaN
# 945           NaN
# 946           NaN
# 947           NaN
# 948           NaN
# 949           NaN
#
# [950 rows x 52 columns]

# %%
nobel = nobel_complete[['awardYear', 'category', 'prizeAmount', 'prizeAmountAdjusted', 'name', 'gender', 'birth_continent']]
nobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   awardYear            950 non-null    int64
#  1   category             950 non-null    object
#  2   prizeAmount          950 non-null    int64
#  3   prizeAmountAdjusted  950 non-null    int64
#  4   name                 950 non-null    object
#  5   gender               923 non-null    object
#  6   birth_continent      923 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 52.1+ KB

# %%
nobel
# Out:
#      awardYear                category  prizeAmount  prizeAmountAdjusted  \
# 0         2001       Economic Sciences     10000000             12295082
# 1         1975                 Physics       630000              3404179
# 2         2004               Chemistry     10000000             11762861
# 3         1982               Chemistry      1150000              3102518
# 4         1979                 Physics       800000              2988048
# 5         2019       Economic Sciences      9000000              9000000
# 6         2019                   Peace      9000000              9000000
# 7         2009               Chemistry     10000000             10958504
# 8         2011                 Physics     10000000             10545557
# 9         1939               Chemistry       148822              4227898
# 10        1905               Chemistry       138089              7615202
# 11        1928               Chemistry       156939              4458494
# 12        1980                   Peace       880000              2889667
# 13        1999               Chemistry      7900000             10049186
# 14        2010               Chemistry     10000000             10819388
# ..         ...                     ...          ...                  ...
# 935       1994                   Peace      7000000              9249471
# 936       1968              Literature       350000              3052326
# 937       1994                   Peace      7000000              9249471
# 938       2008                 Physics     10000000             10926573
# 939       2016  Physiology or Medicine      8000000              8301051
# 940       1986               Chemistry      2000000              4098361
# 941       2005               Chemistry     10000000             11711430
# 942       2000                 Physics      9000000             11333109
# 943       1980               Chemistry       880000              2889667
# 944       1944                   Peace       121841              2510460
# 945       1972                 Physics       480000              3345725
# 946       1954               Chemistry       181647              2640218
# 947       1911               Chemistry       140695              7327865
# 948       1981                   Peace      1000000              2929688
# 949       1963                   Peace       265000              2839286
#
#                                                   name  gender birth_continent
# 0                                    A. Michael Spence    male   North America
# 1                                         Aage N. Bohr    male          Europe
# 2                                    Aaron Ciechanover    male            Asia
# 3                                           Aaron Klug    male          Europe
# 4                                          Abdus Salam    male            Asia
# 5                                     Abhijit Banerjee    male            Asia
# 6                                       Abiy Ahmed Ali    male          Africa
# 7                                        Ada E. Yonath  female            Asia
# 8                                        Adam G. Riess    male   North America
# 9                                      Adolf Butenandt    male          Europe
# 10                                    Adolf von Baeyer    male          Europe
# 11                                       Adolf Windaus    male          Europe
# 12                               Adolfo Pérez Esquivel    male   South America
# 13                                        Ahmed Zewail    male          Africa
# 14                                        Akira Suzuki    male            Asia
# ..                                                 ...     ...             ...
# 935                                      Yasser Arafat    male          Africa
# 936                                  Yasunari Kawabata    male            Asia
# 937                                      Yitzhak Rabin    male            Asia
# 938                                     Yoichiro Nambu    male            Asia
# 939                                   Yoshinori Ohsumi    male            Asia
# 940                                        Yuan T. Lee    male            Asia
# 941                                       Yves Chauvin    male          Europe
# 942                                     Zhores Alferov    male          Europe
# 943                                   Frederick Sanger    male          Europe
# 944           International Committee of the Red Cross     NaN             NaN
# 945                                       John Bardeen    male   North America
# 946                                      Linus Pauling    male   North America
# 947                                        Marie Curie  female          Europe
# 948  Office of the United Nations High Commissioner...     NaN             NaN
# 949           International Committee of the Red Cross     NaN             NaN
#
# [950 rows x 7 columns]

# %%
nobel["prizeAmount"].mean()
# Out:
# 3460596.127368421

# %%
# que categorias hay?
nobel["category"].unique()
# Out:
# array(['Economic Sciences', 'Physics', 'Chemistry', 'Peace',
#        'Physiology or Medicine', 'Literature'], dtype=object)

# %%
# cuantos premios hay de cada categoria?
nobel["category"].value_counts()
# Out:
# category
# Physiology or Medicine    219
# Physics                   213
# Chemistry                 184
# Peace                     134
# Literature                116
# Economic Sciences          84
# Name: count, dtype: int64

# %% [markdown]
# ## Cuanto fue el total de premios por cada categoría?
#
# ---

# %%
grouped = nobel.groupby("category")

# %%
grouped

# %%
grouped.indices
# Out:
# {'Chemistry': array([  2,   3,   7,   9,  10,  11,  13,  14,  15,  17,  19,  39,  62,
#          64,  66,  71,  75,  80,  81,  86,  92, 104, 107, 112, 129, 135,
#         153, 169, 175, 178, 181, 188, 197, 199, 203, 210, 215, 223, 227,
#         239, 247, 249, 258, 264, 265, 268, 272, 274, 280, 282, 284, 289,
#         296, 298, 310, 311, 317, 318, 337, 341, 343, 348, 352, 357, 362,
#         365, 366, 372, 374, 384, 394, 395, 396, 415, 416, 419, 434, 440,
#         442, 444, 446, 448, 450, 455, 456, 459, 461, 463, 465, 469, 475,
#         504, 505, 508, 518, 522, 523, 524, 539, 549, 558, 559, 563, 567,
#         571, 572, 585, 591, 596, 599, 627, 630, 632, 641, 643, 644, 648,
#         659, 661, 666, 667, 668, 671, 673, 679, 681, 686, 713, 715, 717,
#         719, 720, 722, 723, 725, 726, 729, 732, 738, 742, 744, 746, 751,
#         756, 759, 763, 766, 773, 776, 798, 810, 813, 814, 817, 827, 828,
#         829, 832, 839, 848, 853, 855, 862, 866, 880, 885, 886, 888, 889,
#         892, 894, 897, 902, 904, 914, 915, 920, 921, 922, 940, 941, 943,
#         946, 947]),
#  'Economic Sciences': array([  0,   5,  45,  46,  58,  90,  96, 139, 140, 145, 152, 156, 157,
#         180, 187, 193, 207, 219, 231, 232, 246, 250, 269, 279, 283, 295,
#         305, 324, 346, 369, 418, 422, 425, 426, 430, 432, 438, 458, 467,
#         476, 485, 510, 525, 527, 537, 538, 546, 580, 594, 595, 605, 611,
#         636, 637, 657, 669, 670, 678, 700, 708, 716, 724, 734, 737, 739,
#         745, 747, 749, 750, 753, 758, 767, 800, 805, 854, 856, 860, 864,
#         871, 882, 896, 912, 916, 924]),
#  'Literature': array([ 21,  31,  40,  49,  52,  98, 100, 101, 102, 111, 115, 142, 149,
#         159, 170, 177, 201, 202, 220, 221, 233, 235, 237, 253, 257, 259,
#         275, 277, 278, 286, 312, 315, 316, 321, 326, 333, 345, 347, 350,
#         355, 359, 364, 370, 373, 385, 397, 400, 403, 406, 411, 435, 439,
#         441, 454, 468, 479, 480, 482, 483, 492, 501, 506, 511, 516, 556,
#         569, 581, 602, 604, 606, 613, 614, 618, 631, 633, 635, 640, 652,
#         653, 655, 656, 665, 675, 683, 699, 761, 765, 771, 774, 777, 779,
#         780, 784, 786, 788, 796, 799, 803, 836, 840, 842, 850, 861, 867,
#         868, 878, 881, 883, 910, 917, 919, 927, 928, 929, 930, 936]),
#  'Peace': array([  6,  12,  16,  25,  26,  27,  34,  36,  44,  47,  48,  54,  61,
#          65,  72,  78,  79,  82,  95,  99, 116, 119, 120, 126, 137, 146,
#         151, 166, 167, 171, 200, 204, 205, 206, 209, 213, 225, 236, 240,
#         244, 255, 260, 266, 267, 270, 287, 303, 320, 329, 356, 360, 361,
#         377, 386, 387, 388, 389, 390, 391, 392, 393, 433, 447, 449, 471,
#         477, 481, 489, 491, 500, 512, 514, 517, 528, 529, 530, 533, 534,
#         540, 542, 544, 545, 547, 553, 555, 560, 562, 574, 578, 590, 593,
#         603, 607, 608, 609, 612, 615, 616, 617, 619, 620, 628, 634, 639,
#         642, 664, 677, 688, 697, 703, 705, 710, 727, 736, 787, 793, 795,
#         806, 823, 846, 847, 852, 865, 875, 876, 877, 895, 926, 934, 935,
#         937, 944, 948, 949]),
#  'Physics': array([  1,   4,   8,  20,  23,  24,  30,  32,  38,  51,  59,  60,  67,
#          68,  69,  70,  74,  84,  89,  97, 103, 105, 108, 109, 114, 117,
#         118, 122, 125, 127, 128, 130, 133, 141, 143, 144, 155, 162, 163,
#         164, 165, 168, 173, 174, 176, 179, 183, 195, 212, 214, 216, 222,
#         224, 228, 230, 234, 238, 241, 243, 251, 256, 263, 271, 276, 291,
#         292, 297, 301, 306, 307, 308, 323, 327, 328, 330, 335, 336, 338,
#         349, 351, 353, 354, 363, 367, 375, 376, 378, 381, 382, 398, 399,
#         402, 404, 405, 408, 410, 412, 413, 420, 421, 424, 428, 429, 436,
#         445, 451, 453, 457, 460, 462, 470, 472, 487, 495, 498, 499, 509,
#         513, 515, 521, 526, 532, 535, 536, 541, 548, 550, 552, 557, 561,
#         564, 565, 566, 573, 576, 577, 579, 583, 586, 588, 592, 601, 610,
#         621, 622, 623, 629, 647, 650, 651, 654, 658, 674, 676, 682, 684,
#         690, 691, 693, 694, 695, 696, 698, 702, 707, 711, 714, 721, 730,
#         731, 735, 743, 752, 755, 770, 772, 775, 781, 785, 790, 792, 797,
#         801, 802, 808, 822, 833, 834, 835, 844, 851, 870, 872, 879, 884,
#         887, 890, 893, 900, 901, 903, 905, 907, 908, 909, 913, 925, 931,
#         932, 933, 938, 942, 945]),
#  'Physiology or Medicine': array([ 18,  22,  28,  29,  33,  35,  37,  41,  42,  43,  50,  53,  55,
#          56,  57,  63,  73,  76,  77,  83,  85,  87,  88,  91,  93,  94,
#         106, 110, 113, 121, 123, 124, 131, 132, 134, 136, 138, 147, 148,
#         150, 154, 158, 160, 161, 172, 182, 184, 185, 186, 189, 190, 191,
#         192, 194, 196, 198, 208, 211, 217, 218, 226, 229, 242, 245, 248,
#         252, 254, 261, 262, 273, 281, 285, 288, 290, 293, 294, 299, 300,
#         302, 304, 309, 313, 314, 319, 322, 325, 331, 332, 334, 339, 340,
#         342, 344, 358, 368, 371, 379, 380, 383, 401, 407, 409, 414, 417,
#         423, 427, 431, 437, 443, 452, 464, 466, 473, 474, 478, 484, 486,
#         488, 490, 493, 494, 496, 497, 502, 503, 507, 519, 520, 531, 543,
#         551, 554, 568, 570, 575, 582, 584, 587, 589, 597, 598, 600, 624,
#         625, 626, 638, 645, 646, 649, 660, 662, 663, 672, 680, 685, 687,
#         689, 692, 701, 704, 706, 709, 712, 718, 728, 733, 740, 741, 748,
#         754, 757, 760, 762, 764, 768, 769, 778, 782, 783, 789, 791, 794,
#         804, 807, 809, 811, 812, 815, 816, 818, 819, 820, 821, 824, 825,
#         826, 830, 831, 837, 838, 841, 843, 845, 849, 857, 858, 859, 863,
#         869, 873, 874, 891, 898, 899, 906, 911, 918, 923, 939])}

# %%
print(len(grouped))
# Out:
# 6

# %%
# grouped se puede iterar!
for (nombre, grupo) in grouped:
    print(f'Head de {nombre}:')
    print(30*'-')
    print(grupo.head(5), '\n\n')
# Out:
# Head de Chemistry:
# ------------------------------
#     awardYear   category  prizeAmount  prizeAmountAdjusted               name  \
# 2        2004  Chemistry     10000000             11762861  Aaron Ciechanover
# 3        1982  Chemistry      1150000              3102518         Aaron Klug
# 7        2009  Chemistry     10000000             10958504      Ada E. Yonath
# 9        1939  Chemistry       148822              4227898    Adolf Butenandt
# 10       1905  Chemistry       138089              7615202   Adolf von Baeyer
#
#     gender birth_continent
# 2     male            Asia
# 3     male          Europe
# 7   female            Asia
# 9     male          Europe
# 10    male          Europe
#
#
# Head de Economic Sciences:
# ------------------------------
#     awardYear           category  prizeAmount  prizeAmountAdjusted  \
# 0        2001  Economic Sciences     10000000             12295082
# 5        2019  Economic Sciences      9000000              9000000
# 45       2012  Economic Sciences      8000000              8361204
# 46       1998  Economic Sciences      7600000              9713701
# 58       2015  Economic Sciences      8000000              8384572
#
#                  name gender birth_continent
# 0   A. Michael Spence   male   North America
# 5    Abhijit Banerjee   male            Asia
# 45      Alvin E. Roth   male   North America
# 46        Amartya Sen   male            Asia
# 58       Angus Deaton   male          Europe
#
#
# Head de Literature:
# ------------------------------
#     awardYear    category  prizeAmount  prizeAmountAdjusted  \
# 21       1957  Literature       208629              2697789
# 31       1970  Literature       400000              3177966
# 40       2013  Literature      8000000              8365867
# 49       1921  Literature       121573              2532771
# 52       1947  Literature       146115              2914528
#
#                      name  gender birth_continent
# 21           Albert Camus    male          Africa
# 31  Alexandr Solzhenitsyn    male          Europe
# 40            Alice Munro  female   North America
# 49         Anatole France    male          Europe
# 52             André Gide    male          Europe
#
#
# Head de Peace:
# ------------------------------
#     awardYear category  prizeAmount  prizeAmountAdjusted  \
# 6        2019    Peace      9000000              9000000
# 12       1980    Peace       880000              2889667
# 16       2007    Peace     10000000             11301989
# 25       1902    Peace       141847              8059489
# 26       1960    Peace       225987              2664941
#
#                      name gender birth_continent
# 6          Abiy Ahmed Ali   male          Africa
# 12  Adolfo Pérez Esquivel   male   South America
# 16                Al Gore   male   North America
# 25           Albert Gobat   male          Europe
# 26         Albert Luthuli   male          Africa
#
#
# Head de Physics:
# ------------------------------
#     awardYear category  prizeAmount  prizeAmountAdjusted                 name  \
# 1        1975  Physics       630000              3404179         Aage N. Bohr
# 4        1979  Physics       800000              2988048          Abdus Salam
# 8        2011  Physics     10000000             10545557        Adam G. Riess
# 20       1907  Physics       138796              7033581  Albert A. Michelson
# 23       1921  Physics       121573              2532771      Albert Einstein
#
#    gender birth_continent
# 1    male          Europe
# 4    male            Asia
# 8    male   North America
# 20   male          Europe
# 23   male          Europe
#
#
# Head de Physiology or Medicine:
# ------------------------------
#     awardYear                category  prizeAmount  prizeAmountAdjusted  \
# 18       1963  Physiology or Medicine       265000              2839286
# 22       1974  Physiology or Medicine       550000              3263449
# 28       1937  Physiology or Medicine       158463              4716161
# 29       1910  Physiology or Medicine       140703              7130220
# 33       1912  Physiology or Medicine       140476              6753654
#
#                     name gender birth_continent
# 18          Alan Hodgkin   male          Europe
# 22         Albert Claude   male          Europe
# 28  Albert Szent-Györgyi   male          Europe
# 29       Albrecht Kossel   male          Europe
# 33         Alexis Carrel   male          Europe

# %%
phy = grouped.get_group('Physics')

# %%
phy
# Out:
#      awardYear category  prizeAmount  prizeAmountAdjusted  \
# 1         1975  Physics       630000              3404179
# 4         1979  Physics       800000              2988048
# 8         2011  Physics     10000000             10545557
# 20        1907  Physics       138796              7033581
# 23        1921  Physics       121573              2532771
# 24        2007  Physics     10000000             11301989
# 30        1964  Physics       273000              2828039
# 32        2003  Physics     10000000             11807305
# 38        1966  Physics       300000              2784653
# 51        2010  Physics     10000000             10819388
# 59        2003  Physics     10000000             11807305
# 60        1974  Physics       550000              3263449
# 67        1978  Physics       725000              2898454
# 68        2018  Physics      9000000              9000000
# 69        2015  Physics      8000000              8384572
# ..         ...      ...          ...                  ...
# 900       1932  Physics       171753              5279293
# 901       1901  Physics       150782              8567159
# 903       1911  Physics       140695              7327865
# 905       2009  Physics     10000000             10958504
# 907       1983  Physics      1500000              3715324
# 908       1956  Physics       200123              2699501
# 909       1915  Physics       149223              6217625
# 913       1997  Physics      7500000              9572839
# 925       1955  Physics       190214              2681588
# 931       2001  Physics     10000000             12295082
# 932       1989  Physics      3000000              5242311
# 933       1945  Physics       121333              2499993
# 938       2008  Physics     10000000             10926573
# 942       2000  Physics      9000000             11333109
# 945       1972  Physics       480000              3345725
#
#                        name gender birth_continent
# 1              Aage N. Bohr   male          Europe
# 4               Abdus Salam   male            Asia
# 8             Adam G. Riess   male   North America
# 20      Albert A. Michelson   male          Europe
# 23          Albert Einstein   male          Europe
# 24              Albert Fert   male          Europe
# 30   Aleksandr M. Prokhorov   male         Oceania
# 32         Alexei Abrikosov   male          Europe
# 38           Alfred Kastler   male          Europe
# 51               Andre Geim   male          Europe
# 59       Anthony J. Leggett   male          Europe
# 60            Antony Hewish   male          Europe
# 67             Arno Penzias   male          Europe
# 68            Arthur Ashkin   male   North America
# 69       Arthur B. McDonald   male   North America
# ..                      ...    ...             ...
# 900       Werner Heisenberg   male          Europe
# 901  Wilhelm Conrad Röntgen   male          Europe
# 903            Wilhelm Wien   male          Europe
# 905        Willard S. Boyle   male   North America
# 907       William A. Fowler   male   North America
# 908     William B. Shockley   male          Europe
# 909           William Bragg   male          Europe
# 913     William D. Phillips   male   North America
# 925          Willis E. Lamb   male   North America
# 931       Wolfgang Ketterle   male          Europe
# 932           Wolfgang Paul   male          Europe
# 933          Wolfgang Pauli   male          Europe
# 938          Yoichiro Nambu   male            Asia
# 942          Zhores Alferov   male          Europe
# 945            John Bardeen   male   North America
#
# [213 rows x 7 columns]

# %%
grouped.sum(numeric_only=True)
# Out:
#                         awardYear  prizeAmount  prizeAmountAdjusted
# category
# Chemistry                  362912    667787418           1151447726
# Economic Sciences          167674    512891000            658373449
# Literature                 227468    289282102            649397731
# Peace                      263248    418733807            825963521
# Physics                    419837    725890928           1296526352
# Physiology or Medicine     431508    672981066           1256687857

# %%
grouped["prizeAmount"].sum()
# Out:
# category
# Chemistry                 667787418
# Economic Sciences         512891000
# Literature                289282102
# Peace                     418733807
# Physics                   725890928
# Physiology or Medicine    672981066
# Name: prizeAmount, dtype: int64

# %%
grouped[["prizeAmount", "prizeAmountAdjusted"]].mean()
# Out:
#                          prizeAmount  prizeAmountAdjusted
# category
# Chemistry               3.629279e+06         6.257868e+06
# Economic Sciences       6.105845e+06         7.837779e+06
# Literature              2.493811e+06         5.598256e+06
# Peace                   3.124879e+06         6.163907e+06
# Physics                 3.407939e+06         6.086978e+06
# Physiology or Medicine  3.072973e+06         5.738301e+06

# %% [markdown]
# # Group en pandas

# %%
dx = pd.DataFrame({
    "key":list("ABCABC"),
    "data":[1,2,3,4,5,6]
})

dx
# Out:
#   key  data
# 0   A     1
# 1   B     2
# 2   C     3
# 3   A     4
# 4   B     5
# 5   C     6

# %% [markdown]
# ### Conceptos: Split - Apply - Combine

# %%
# agrupamos
dx_grouped = dx.groupby("key")
dx_grouped

# %% [markdown]
# ![2023-05-07-215436_3286x1080_scrot.png](data:image/png;base64,...)

# %%
dx_grouped.indices
# Out:
# {'A': array([0, 3]), 'B': array([1, 4]), 'C': array([2, 5])}

# %%
# aplicamos una funcion de agregacion sum()
dx_grouped.sum()
# Out:
#      data
# key
# A       5
# B       7
# C       9

# %%
dx.groupby("key").sum()
# Out:
#      data
# key
# A       5
# B       7
# C       9

# %% [markdown]
# # Agrupar y agregar

# %% [markdown]
# Pandas permite agrupar, por:
#
# * un nombre o varios nombres de columnas
# * lista de valores,
# * serie
# * un diccionario
# * una funcion

# %%
df1 = pd.DataFrame({"key1" : ["a", "a", "a", "a", None, "b", "b", "b", "b", "a", None],
                   "key2" : pd.Series([1, 2, 1, 2, 1, 2, 1, 1, 2, None, 1], dtype="Int64"),
                   "data1" : np.random.standard_normal(11),
                   "data2" : np.random.standard_normal(11)})
df1
# Out:
#     key1  key2     data1     data2
# 0      a     1 -0.204708 -1.296221
# 1      a     2  0.478943  0.274992
# 2      a     1 -0.519439  0.228913
# 3      a     2 -0.555730  1.352917
# 4   None     1  1.965781  0.886429
# 5      b     2  1.393406 -2.001637
# 6      b     1  0.092908 -0.371843
# 7      b     1  0.281746  1.669025
# 8      b     2  0.769023 -0.438570
# 9      a  <NA>  1.246435 -0.539741
# 10  None     1  1.007189  0.476985

# %%
df1.groupby("key1")

# %%
# df1.groupby("key1").indices

# %%
df1.groupby("key1").mean()
# Out:
#       key2     data1     data2
# key1
# a      1.5  0.089100  0.004172
# b      1.5  0.634271 -0.285756

# %%
means_jg = df1.groupby(["key1", "key2"]).mean()
means_jg
# Out:
#               data1     data2
# key1 key2
# a    1    -0.362073 -0.533654
#      2    -0.038393  0.813954
# b    1     0.187327  0.648591
#      2     1.081214 -1.220104

# %%
df1.groupby(["key1", "key2"]).mean()
# Out:
#               data1     data2
# key1 key2
# a    1    -0.362073 -0.533654
#      2    -0.038393  0.813954
# b    1     0.187327  0.648591
#      2     1.081214 -1.220104

# %%
df1.groupby(["key1"]).mean()
# Out:
#       key2     data1     data2
# key1
# a      1.5  0.089100  0.004172
# b      1.5  0.634271 -0.285756

# %%
df1.groupby("key1", dropna=False).mean()
# Out:
#       key2     data1     data2
# key1
# a      1.5  0.089100  0.004172
# b      1.5  0.634271 -0.285756
# NaN    1.0  1.486485  0.681707

# %%
df1.groupby(["key1", "key2"], dropna=False).mean()
# Out:
#               data1     data2
# key1 key2
# a    1    -0.362073 -0.533654
#      2    -0.038393  0.813954
#      <NA>  1.246435 -0.539741
# b    1     0.187327  0.648591
#      2     1.081214 -1.220104
# NaN  1     1.486485  0.681707

# %% [markdown]
# ## Agrupar con dict, listas o series.

# %%
# creamos un ejemplo
people = pd.DataFrame(np.random.standard_normal((5, 5)),
                      columns=["a", "b", "c", "d", "e"],
                      index=["Joe", "Steve", "Wanda", "Jill", "Trey"])
people.iloc[2:3, [1, 2]] = np.nan # agregamos algunos NA
people
# Out:
#               a         b         c         d         e
# Joe    3.248944 -1.021228 -0.577087  0.124121  0.302614
# Steve  0.523772  0.000940  1.343810 -0.713544 -0.831154
# Wanda -2.370232       NaN       NaN  0.560145 -1.265934
# Jill   0.119827 -1.063512  0.332883 -2.359419 -0.199543
# Trey  -1.541996 -0.970736 -1.307030  0.286350  0.377984

# %%
# Si pasamos un diccionario indicamos cada indice en que grupo cae
grp_names = {"Joe": "AA", "Steve": "AA", "Wanda": "BB", "Jill": "BB", "Trey": "BB"}
gdict = people.groupby(grp_names)
gdict.sum()
# Out:
#            a         b         c         d         e
# AA  3.772716 -1.020287  0.766722 -0.589423 -0.528540
# BB -3.792400 -2.034248 -0.974148 -1.512924 -1.087493

# %%
ix = ["AA", "AA", "BB", "BB", "BB"]
gseries = people.groupby(ix)
gseries.count()
# Out:
#     a  b  c  d  e
# AA  2  2  2  2  2
# BB  3  2  2  3  3

# %%
ss = pd.Series(data = ["AA", "AA", "BB", "BB", "BB"],
               index = people.index)

# %%
ss
# Out:
# Joe      AA
# Steve    AA
# Wanda    BB
# Jill     BB
# Trey     BB
# dtype: object

# %% [markdown]
# ### agrupar con una funcion

# %%
people
# Out:
#               a         b         c         d         e
# Joe    3.248944 -1.021228 -0.577087  0.124121  0.302614
# Steve  0.523772  0.000940  1.343810 -0.713544 -0.831154
# Wanda -2.370232       NaN       NaN  0.560145 -1.265934
# Jill   0.119827 -1.063512  0.332883 -2.359419 -0.199543
# Trey  -1.541996 -0.970736 -1.307030  0.286350  0.377984

# %%
def tiene_J(val):
  print(val)
  if "J" in val:
    return "CJ"
  else:
    return "SJ"

# %%
g2 = people.groupby(tiene_J).max()
g2
# Out:
# Joe
# Steve
# Wanda
# Jill
# Trey
#            a         b         c         d         e
# CJ  3.248944 -1.021228  0.332883  0.124121  0.302614
# SJ  0.523772  0.000940  1.343810  0.560145  0.377984

# %% [markdown]
# # Seleccionar columnas

# %%
df1
# Out:
#     key1  key2     data1     data2
# 0      a     1 -0.204708 -1.296221
# 1      a     2  0.478943  0.274992
# 2      a     1 -0.519439  0.228913
# 3      a     2 -0.555730  1.352917
# 4   None     1  1.965781  0.886429
# 5      b     2  1.393406 -2.001637
# 6      b     1  0.092908 -0.371843
# 7      b     1  0.281746  1.669025
# 8      b     2  0.769023 -0.438570
# 9      a  <NA>  1.246435 -0.539741
# 10  None     1  1.007189  0.476985

# %%
df1.groupby(["key1"]).sum()
# Out:
#       key2     data1     data2
# key1
# a        6  0.445501  0.020859
# b        6  2.537082 -1.143024

# %%
# ejemplo agrupamos por key1, seleccionamos columna data1 y la sumarizamos
df1.groupby("key1")["data1"].sum()
# Out:
# key1
# a    0.445501
# b    2.537082
# Name: data1, dtype: float64

# %%
df1.groupby(["key1"])["data1"]

# %%
df1.groupby(["key1"])["data1"].sum()
# Out:
# key1
# a    0.445501
# b    2.537082
# Name: data1, dtype: float64

# %%
df1.groupby(["key1"])[["data1"]]

# %%
df1.groupby(["key1"])[["data1"]].sum()
# Out:
#          data1
# key1
# a     0.445501
# b     2.537082

# %%
df1.groupby(["key1"])[["data1", "data2"]].sum()
# Out:
#          data1     data2
# key1
# a     0.445501  0.020859
# b     2.537082 -1.143024

# %% [markdown]
# # Aplicar: agg()

# %%
rng = np.random.RandomState(0)

df = pd.DataFrame({
    'key': ['A', 'B', 'C', 'A', 'B', 'C'],
    'data1': range(6),
    'data2': rng.randint(0, 10, 6)},
    columns = ['key', 'data1', 'data2'])

df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby('key').agg(['min', 'median','max'])
# Out:
#     data1            data2
#       min median max   min median max
# key
# A       0    1.5   3     3    4.0   5
# B       1    2.5   4     0    3.5   7
# C       2    3.5   5     3    6.0   9

# %%
df.groupby('key').agg([("Mínimo", 'min'), ("Promedio", 'median') , ("Máximo", 'max')])
# Out:
#      data1                  data2
#     Mínimo Promedio Máximo Mínimo Promedio Máximo
# key
# A        0      1.5      3      3      4.0      5
# B        1      2.5      4      0      3.5      7
# C        2      3.5      5      3      6.0      9

# %%
df.groupby('key').agg(
    {'data1': 'min',
     'data2': 'max'})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9

# %%
def peak_to_peak(arr):
  return arr.max() - arr.min()

df.groupby('key').agg(peak_to_peak)
# Out:
#      data1  data2
# key
# A        3      2
# B        3      7
# C        3      6
