# %% [markdown]
# <a href="https://colab.research.google.com/github/Danangellotti/Ciencia_de_Datos_UGR_24/blob/main/Ejercicios_Lectura_Archivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios Lectura de archivos

# %% [markdown]
# ### Preparación

# %% [markdown]
# Ejecutar estas celdas antes de resolver los ejercicios

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c775bf5b-3d7d-4591-a5a9-19d1d7a5ae62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c775bf5b-3d7d-4591-a5a9-19d1d7a5ae62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -o "u3-lectura-de-datasets-archivos (1).zip"
# Out:
# Archive:  u3-lectura-de-datasets-archivos (1).zip
#   inflating: examples/array_ex.txt
#   inflating: examples/csv_mindex.csv
#   inflating: examples/ex1.csv
#   inflating: examples/ex1.xlsx
#  extracting: examples/ex2.csv
#   inflating: examples/ex3pipe.txt
#   inflating: examples/ex3.txt
#   inflating: examples/ex4.csv
#   inflating: examples/ex5.csv
#   inflating: examples/ex6.csv
#   inflating: examples/ex7.csv
#   inflating: examples/example.json
#   inflating: examples/fdic_failed_bank_list.html
#   inflating: examples/ipython_bug.py
#   inflating: examples/macrodata.csv
#   inflating: examples/out.csv
#   inflating: examples/segismundo.txt
#   inflating: examples/spx.csv
#   inflating: examples/stinkbug.png
#   inflating: examples/stock_px.csv
#   inflating: examples/test_file.csv
#   inflating: examples/tseries.csv
#   inflating: examples/volume.csv
#   inflating: examples/yahoo_price.pkl
#   inflating: examples/yahoo_volume.pkl
#   inflating: ejercicios/clima-multi.txt
# ...

# %%
import pandas as pd

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# El archivo `ejercicios/modelos.csv` tiene los modelos de autos más vendidos de abril. Debes cargar dichos datos en un Dataframe.
#
# * a) Ejecutar comandos de tu entorno (shell) para inspeccionar los datos.
# * b) Descubres que el archivo no tiene cabecera, cargar los datos suponiendo que las columnas son: puesto, modelo, cantidad.
# * (_Utilizar celdas distintas para cada respuesta_)

# %%
# 1a)
# Comando del shell para mostrar el contenido del archivo
# Comando del shell para explorar las primeras líneas del archivo
# !head ejercicios/modelos.csv

# tu respuesta
# Out:
# 1,FiaCronos,2675
# 2,Peugeo208,1872
# 3,ChevroleCruze,1212
# 4,ToyotEtios,1109
# 5,ToyotCorollCross,870
# 6,ToyotYaris,823
# 7,ToyotCorolla,749
# 8,VolkswageGoTrend,736
# 9,CitroeCCactus,580
# 10,RenaulSandero,578

# %%
# 1b)
# Cargar el archivo modelos.csv sin cabecera, asignando manualmente los nombres de las columnas
columnas = ['puesto', 'modelo', 'cantidad']
df_modelos = pd.read_csv('ejercicios/modelos.csv', header=None, names=columnas)

# Mostrar el contenido del DataFrame
df_modelos.head()
# tu respuesta
# Out:
#    puesto            modelo  cantidad
# 0       1         FiaCronos      2675
# 1       2         Peugeo208      1872
# 2       3     ChevroleCruze      1212
# 3       4        ToyotEtios      1109
# 4       5  ToyotCorollCross       870

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# El archivo `ejercicios/clima.unl` tiene datos de meterología de un día. La tarea es informar el promedio de temperatura de ese día.

# %% [markdown]
# * a) Ejectuar comados de tu entorno para inspeccionar el contenido. (Descubres que tienen un formato especial)
# * b) Cargar el archivo en un dataframe y guardarlo en la variable `ej2` y mostrarlo en el notebook.
# * c) Usar el Dataframe de `ej2` para informar el promedio de temperatura (TEMP) de ese día.

# %%
# 2a)
# Comando del shell para mostrar las primeras líneas del archivo clima.unl
# Muestra las últimas 10 líneas del archivo
# !tail ejercicios/clima-multi.txt


# tu respuesta
# Out:
#  20230319    14  37.0   30  1005.7   20   11     CATAMARCA_AERO
#  20230319    15  37.0   29  1004.8   20   17     CATAMARCA_AERO
#  20230319    16  38.8   24  1003.4   20   11     CATAMARCA_AERO
#  20230319    17  38.6   24  1002.9   20   17     CATAMARCA_AERO
#  20230319    18  36.8   27  1003.2   20   24     CATAMARCA_AERO
#  20230319    19  34.8   32  1004.0   20   26     CATAMARCA_AERO
#  20230319    20  32.8   39  1004.9   20   20     CATAMARCA_AERO
#  20230319    21  31.4   42  1005.2   20   22     CATAMARCA_AERO
#  20230319    22  30.1   42  1006.1   20   19     CATAMARCA_AERO
#  20230319    23  29.2   43  1006.7   20   15     CATAMARCA_AERO

# %%
# 2b)
# Suponiendo que el archivo está separado por espacios (por ejemplo)
ej2 = pd.read_csv('ejercicios/clima.unl', delimiter='|', header=0)

# Mostrar el contenido del DataFrame
ej2.head()
# tu respuesta
# Out:
#       FECHA  HORA  TEMP  HUM     PNM   DD  FF          NOMBRE
# 0  20230319     1   8.1   84  1516.0  200   9  BARILOCHE AERO
# 1  20230319     2   8.3   82  1515.0  190   9  BARILOCHE AERO
# 2  20230319     3   8.3   80  1514.0  200   7  BARILOCHE AERO
# 3  20230319     4   7.8   79  1512.0  200   9  BARILOCHE AERO
# 4  20230319     5   7.2   83  1509.0  200  11  BARILOCHE AERO

# %%
# 2c)
# Calcular el promedio de la columna TEMP
promedio_temp = ej2['TEMP'].mean()

# Mostrar el promedio de temperatura
print(f"El promedio de la temperatura es: {promedio_temp}")

# tu respuesta
# Out:
# El promedio de la temperatura es: 12.169565217391305

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# El archivo `ejercicios/clima-multi.txt` es similar al clima.txt, salvo que tiene información de dos estaciones de metereología. La tarea es informar el promedio de humedad (HUM) de los dos lugares.
#
# * a) Explorar el archivo con comandos del shell
# * b) Generar un dataframe con el archivo, almacenarlo en la variable ej3 y mostrar su contenido
# * c) Calcular y mostrar el promedio de Humedad de las dos estaciones.

# %% [markdown]
# _Ayuda_: Si se crea el dataframe usando `index_col`, se pueden 'segmentar' los datos accediendolos con `loc[...]`

# %%
# 3a)
# Muestra todo el contenido del archivo
# !cat ejercicios/clima-multi.txt

# tu respuesta
# Out:
# FECHA     HORA  TEMP   HUM   PNM    DD    FF     NOMBRE
#  20230319     0   8.2   86  1515.0  190    9     BARILOCHE_AERO
#  20230319     1   8.1   84  1516.0  200    9     BARILOCHE_AERO
#  20230319     2   8.3   82  1515.0  190    9     BARILOCHE_AERO
#  20230319     3   8.3   80  1514.0  200    7     BARILOCHE_AERO
#  20230319     4   7.8   79  1512.0  200    9     BARILOCHE_AERO
#  20230319     5   7.2   83  1509.0  200   11     BARILOCHE_AERO
#  20230319     6   6.6   78  1511.0  200    9     BARILOCHE_AERO
#  20230319     7   6.2   81  1510.0  190    9     BARILOCHE_AERO
#  20230319     8   6.5   77  1507.0  180   13     BARILOCHE_AERO
#  20230319     9   6.9   70  1507.0  200    9     BARILOCHE_AERO
#  20230319    10  10.1   71  1509.0  190    6     BARILOCHE_AERO
#  20230319    11  12.3   63  1512.0  990    6     BARILOCHE_AERO
#  20230319    12  13.7   57  1511.0  290   11     BARILOCHE_AERO
#  20230319    13  14.9   41  1507.0  300   13     BARILOCHE_AERO
# ...

# %%
# 3b)
# Cargar el archivo clima-multi.txt, usando la primera columna como índice (index_col=0)
ej3 = pd.read_csv('ejercicios/clima-multi.txt', delimiter='\s+', index_col=0)

# Mostrar el contenido del DataFrame
ej3.head()
# tu respuesta
# Out:
#           HORA  TEMP  HUM     PNM   DD  FF          NOMBRE
# FECHA
# 20230319     0   8.2   86  1515.0  190   9  BARILOCHE_AERO
# 20230319     1   8.1   84  1516.0  200   9  BARILOCHE_AERO
# 20230319     2   8.3   82  1515.0  190   9  BARILOCHE_AERO
# 20230319     3   8.3   80  1514.0  200   7  BARILOCHE_AERO
# 20230319     4   7.8   79  1512.0  200   9  BARILOCHE_AERO

# %%
# 3c)
# Calcular el promedio de la columna 'HUM' (Humedad)
promedio_humedad = ej3['HUM'].mean()

# Mostrar el promedio de humedad de las dos estaciones
print(f"El promedio de la humedad de las dos estaciones es: {promedio_humedad}")
# tu respuesta
# Out:
# El promedio de la humedad de las dos estaciones es: 50.875
