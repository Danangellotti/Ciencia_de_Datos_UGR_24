# %% [markdown]
# <a href="https://colab.research.google.com/github/Danangellotti/Ciencia_de_Datos_UGR_24/blob/main/Copia_de_Temas_Optativos_Estructura_gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Como organizar gdrive
#
# Ya vimos como que existen templates para la organización de proyectos. Uno de ellos es [cookiecutter](https://www.cookiecutter.io/).
#
# Ahora vamos a replicar todo esto dentro de gdrive.
#
# Esta notebook se puede guardar y utilizar para inicializar los proyectos.

# %% [markdown]
# ## Paso 01
#
# Debemos instalar cookeicutter.

# %%
# !pip install -q cookiecutter
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.5 MB/s eta 0:00:00

# %% [markdown]
# ## Paso 02
#
# Debemos montar nuestro gdrive.

# %% [markdown]
# Al ejecutar la celda para montar gdrive nos aparece un cartel para conectarnos aa gdrive. Debemos seleccionar `Connect to Google Drive`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Luego debemos seleccionar la cuenta con la que nos queremos conectar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ahora debemos presionar `Continuar`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Luego aparece una pantalla donde debemos seleccionar los permisos que le tenemos que otorgar a colab sobre gdrive. Seleccionamos `todos` y nos vamos al final de la página y presionamos nuevamente `Continuar`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Luego de este último `Continuar` vamos a tener montado nuestro gdrive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Lo podemos verificar en la barra izquierda en la pestaña de directorios

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Paso 03
#
# Ahora nos vamos a crear la carpeta de trabajo, recordar que debe ser dentro de `/content/drive/MyDrive`.
#
# En este ejemplo vamos a crear una carpeta llamada `practicas` dentro del raiz de gdrive.
#
# Luego dentro del directorio de `practicas` vamos a crear un que se llama `sai` (seminario de actualización I).

# %%
DIRECTORIO_BASE:str='/content/drive/MyDrive/practicas/sai' # no debe terminar con la / o con \\

# %%
# !mkdir -p $DIRECTORIO_BASE

# %% [markdown]
# ## Paso 04
#
# Vamos a crear la estructura del proyecto.

# %%
# !cookiecutter -c v1 https://github.com/drivendata/cookiecutter-data-science -f --output-dir $DIRECTORIO_BASE
# Out:
#   [1/8] project_name (project_name): practica_1
#   [2/8] repo_name (practica_1):
#   [3/8] author_name (Your name (or your organization/company/team)):
#   [4/8] description (A short description of the project.):
#   [5/8] Select open_source_license
#     1 - MIT
#     2 - BSD-3-Clause
#     3 - No license file
#     Choose from [1/2/3] (1): 1
#   [6/8] s3_bucket ([OPTIONAL] your-bucket-for-syncing-data (do not include 's3://')):
#   [7/8] aws_profile (default):
#   [8/8] Select python_interpreter
#     1 - python3
#     2 - python
#     Choose from [1/2] (1): 1
#
#
# ...
# *** DEPRECATION WARNING ***
#
# Cookiecutter data science is moving to v2 soon, which will entail using
# the command `ccds ...` rather than `cookiecutter ...`. The cookiecutter command
# will continue to work, and this version of the template will still be available.
# To use the legacy template, you will need to explicitly use `-c v1` to select it.
#
# ...

# %% [markdown]
# ## Paso 05
#
# Como estamos trabajando con notebook vamos a crear nuestra notebook de trabajo, para esto habrimos gdrive en la carpeta y dentro de la carpeta notebooks y creamos la notebook.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Luego de está acción se abrirá el notebook creado dentro de la estructura y de esta forma que ordenado.

# %% [markdown]
# ```
# IMPORTANTE:
#
# Una vez que realizamos este trabajo podemos remover los archivos o directorios que no vamos a utilizar.
#
# Recordar que cuando trabajemos con datasets los deberemos almacenar dentro de la carpeta data/[raw|interim|processed].
#
# ```
